# %% [markdown]
# In this notebook we use GCN to analyze the POIs networks

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/Colab\ Notebooks
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Colab Notebooks'
# /content/drive/MyDrive/Colab Notebooks

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import keras
from keras.layers import Dense
from keras.models import Sequential
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torchtext
import torch
from torch.nn import Linear
from torch_geometric.nn import GCNConv
import torch_geometric
import itertools
import nltk
import spacy
import random
from tqdm import tqdm
import time
from IPython.display import Javascript

# %%
import numpy as np
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import math
from collections import Counter
import random
import csv
import os
import sys

# %%
random.seed(10)

# %%
df = pd.read_csv('./datasets/nyc_label.csv')

# %%
df.tail(10)
# Out:
#       Unnamed: 0                                 Label (Grouping)_x  \
# 2155        2155  Census Tract 279, Richmond County, New York!!E...
# 2156        2156  Census Tract 291.02, Richmond County, New York...
# 2157        2157  Census Tract 291.03, Richmond County, New York...
# 2158        2158  Census Tract 291.04, Richmond County, New York...
# 2159        2159  Census Tract 303.01, Richmond County, New York...
# 2160        2160  Census Tract 303.02, Richmond County, New York...
# 2161        2161  Census Tract 319.01, Richmond County, New York...
# 2162        2162  Census Tract 319.02, Richmond County, New York...
# 2163        2163  Census Tract 323, Richmond County, New York!!E...
# 2164        2164  Census Tract 9901, Richmond County, New York!!...
#
#      Own children of the householder under 6 years  \
# 2155                                           106
# 2156                                           338
# 2157                                           424
# 2158                                           583
# 2159                                           247
# 2160                                           320
# 2161                                           139
# 2162                                           493
# 2163                                           108
# 2164                                             0
#
#      Own children of the householder 6 to 17 years  \
# 2155                                           301
# 2156                                           398
# 2157                                         1,062
# 2158                                         1,246
# 2159                                           786
# 2160                                         1,184
# 2161                                           484
# 2162                                           913
# 2163                                           135
# 2164                                             0
#
#      Mean travel time to work (minutes) Median household income (dollars)  \
# 2155                                 33                            91,944
# 2156                                 47                            89,167
# 2157                               39.6                            74,732
# 2158                               43.5                            87,853
# 2159                               48.3                            65,469
# 2160                               47.7                            84,630
# 2161                               39.9                            23,098
# 2162                               39.5                            23,289
# 2163                                 48                            64,250
# 2164                                  -                                 -
#
#      Mean household income (dollars) Total housing units  \
# 2155                         135,774                 668
# 2156                          97,174               1,054
# 2157                          88,155               2,760
# 2158                         102,142               2,428
# 2159                          75,912               1,900
# 2160                          88,335               2,093
# 2161                          32,494               1,185
# 2162                          45,694               1,856
# 2163                          76,485                 526
# 2164                               -                   0
#
#      Homeowner vacancy rate Rental vacancy rate  ...        geoid  \
# 2155                    2.6                10.8  ...  36085027900
# 2156                      0                 9.5  ...  36085029102
# 2157                    1.8                 5.2  ...  36085029103
# 2158                      0                   0  ...  36085029104
# 2159                      0                   0  ...  36085030301
# 2160                    2.2                11.4  ...  36085030302
# 2161                    3.1                 7.6  ...  36085031901
# 2162                   18.6                 7.7  ...  36085031902
# 2163                    7.3                   0  ...  36085032300
# 2164                      -                   -  ...  36085990100
#
#                                 typo USPS    ALAND    AWATER ALAND_SQMI  \
# 2155          MHI - Stable Exclusion   NY  5243636    177359      2.025
# 2156   MHI - Advanced Gentrification   NY  9241350   1628913      3.568
# 2157         MHI - Ongoing Exclusion   NY  2030882       533      0.784
# 2158         MHI - Ongoing Exclusion   NY  1541565         0      0.595
# 2159          MHI - Stable Exclusion   NY   719281         0      0.278
# 2160         MHI - Ongoing Exclusion   NY   908763         0      0.351
# 2161     LI - Ongoing Gentrification   NY   388050         0      0.150
# 2162  LI - At Risk of Gentrification   NY   690539    296692      0.267
# 2163          MHI - Stable Exclusion   NY  3869216    462391      1.494
# 2164                    Missing Data   NY        0  80253318      0.000
#
#      AWATER_SQMI   INTPTLAT  \
# 2155       0.068  40.575221
# 2156       0.629  40.611198
# 2157       0.000  40.603550
# 2158       0.000  40.613723
# 2159       0.000  40.618920
# 2160       0.000  40.623529
# 2161       0.000  40.630303
# 2162       0.115  40.637921
# 2163       0.179  40.636927
# 2164      30.986  40.525549
#
#      INTPTLONG                                                                                                                               \
# 2155                                         -74.155219
# 2156                                         -74.190693
# 2157                                         -74.171136
# 2158                                         -74.163503
# 2159                                         -74.156120
# 2160                                         -74.158743
# 2161                                         -74.163321
# 2162                                         -74.165570
# 2163                                         -74.176144
# 2164                                         -74.108584
#
#      label
# 2155      0
# 2156      1
# 2157      0
# 2158      0
# 2159      0
# 2160      0
# 2161      1
# 2162      1
# 2163      0
# 2164      0
#
# [10 rows x 78 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Label (Grouping)_x',
#        'Own children of the householder under 6 years',
#        'Own children of the householder 6 to 17 years',
#        'Mean travel time to work (minutes)',
#        'Median household income (dollars)', 'Mean household income (dollars)',
#        'Total housing units', 'Homeowner vacancy rate', 'Rental vacancy rate',
#        'ROOM Median rooms', 'VALUE Median (dollars)',
#        'SELECTED MONTHLY OWNER COSTS (SMOC) Housing units with a mortgage Median (dollars)',
#        'SELECTED MONTHLY OWNER COSTS (SMOC) Housing units without a mortgage Median (dollars)',
#        'GROSS RENT Occupied units paying rent Median (dollars)',
#        'Population in households',
#        'YEAR OF ENTRY Population born outside the United States',
#        'YEAR OF ENTRY Foreign born', 'Total households', 'Total population',
#        'Sex ratio (males per 100 females)', 'Median age (years)', 'tract_numb',
#        'Label (Grouping)_y', 'Unemployment Rate',
#        'Agriculture, forestry, fishing and hunting, and mining',
#        'Construction', 'Manufacturing', 'Wholesale trade', 'Retail trade',
#        'Transportation and warehousing, and utilities', 'Information',
#        'Finance and insurance, and real estate and rental and leasing',
#        'Professional, scientific, and management, and administrative and waste management services',
#        'Educational services, and health care and social assistance',
#        'Arts, entertainment, and recreation, and accommodation and food services',
#        'Other services, except public administration', 'Public administration',
#        'INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS) Less than $10,000',
#        'HEALTH INSURANCE COVERAGE With health insurance coverage',
#        'HEALTH INSURANCE COVERAGE With private health insurance',
#        'YEAR STRUCTURE BUILT Built 2014 or later',
#        'YEAR STRUCTURE BUILT Built 2010 to 2013',
#        'HOUSING TENURE Renter-occupied',
#        'YEAR HOUSEHOLDER MOVED INTO UNIT Moved in 2015 or later',
#        'YEAR HOUSEHOLDER MOVED INTO UNIT Moved in 2010 to 2014',
#        'VEHICLES AVAILABLE No vehicles available',
#        'VEHICLES AVAILABLE 2 vehicles available',
#        'VEHICLES AVAILABLE 3 or more vehicles available',
#        'OCCUPANTS PER ROOM 1.01 to 1.50', 'OCCUPANTS PER ROOM 1.51 or more',
#        'MORTGAGE STATUS Owner-occupied units Housing units with a mortgage',
#        '65 years and over',
#        'MARITAL STATUS Males 15 years and over Never married',
#        'MARITAL STATUS Females 15 years and over Never married',
#        'EDUCATIONAL ATTAINMENT Less than 9th grade',
#        'EDUCATIONAL ATTAINMENT 9th to 12th grade, no diploma',
#        'Percent bachelor's degree or higher',
#        'PLACE OF BIRTH Native Different state',
#        'SEX AND AGE 62 years and over', 'White', 'Black or African American',
#        'American Indian and Alaska Native', 'Asian',
#        'Hispanic or Latino (of any race)', 'tract', 'LOGRECNO', 'GEOID',
#        'geoid', 'typo', 'USPS', 'ALAND', 'AWATER', 'ALAND_SQMI', 'AWATER_SQMI',
#        'INTPTLAT',
#        'INTPTLONG                                                                                                                             ',
#        'label '],
#       dtype='object')

# %%
ids = df['GEOID']
labels = df['label ']
lats = df['INTPTLAT']
longs = df['INTPTLONG                                                                                                                             ']

# %%
nyc_lat_n = 40.913873
nyc_lat_s = 40.499471
nyc_long_w = -74.243356
nyc_long_e = -73.704582

# %%
tracts = pd.DataFrame(list(zip(ids, lats, longs, labels)))
tracts.columns = ['id', 'lat', 'long', 'label']

# %%
tracts.describe()
# Out:
#                lat         long        label
# count  2165.000000  2165.000000  2165.000000
# mean     40.716169   -73.915631     0.242956
# std       0.084090     0.086931     0.428968
# min      40.499471   -74.243356     0.000000
# 25%      40.649996   -73.966678     0.000000
# 50%      40.706580   -73.918952     0.000000
# 75%      40.769097   -73.860841     0.000000
# max      40.913873   -73.704582     1.000000

# %%
tracts.tail(10)
# Out:
#                       id        lat       long  label
# 2155  14000US36085027900  40.575221 -74.155219      0
# 2156  14000US36085029102  40.611198 -74.190693      1
# 2157  14000US36085029103  40.603550 -74.171136      0
# 2158  14000US36085029104  40.613723 -74.163503      0
# 2159  14000US36085030301  40.618920 -74.156120      0
# 2160  14000US36085030302  40.623529 -74.158743      0
# 2161  14000US36085031901  40.630303 -74.163321      1
# 2162  14000US36085031902  40.637921 -74.165570      1
# 2163  14000US36085032300  40.636927 -74.176144      0
# 2164  14000US36085990100  40.525549 -74.108584      0

# %%
for index, row in tracts.iterrows():
    if (row['lat'] > nyc_lat_n or row['lat'] < nyc_lat_s or
            row['long'] > nyc_long_e or row['long'] < nyc_long_w):
        tracts = tracts.drop([index])

# %%
city_graph = nx.Graph()
color_map = []
for index, row in tracts.iterrows():
    city_graph.add_node((row['long'], row['lat']),
                        pos=(row['long'], row['lat']),
                        label=row['label'])
    if row['label'] == 1:
        color_map.append('purple')
    else:
        color_map.append('lightblue')

# %%
plt.figure(figsize=(10, 12))

pos=nx.get_node_attributes(city_graph,'pos')
nx.draw(city_graph, pos=pos,
        node_color=color_map, 
        with_labels=False,
        node_size=70)

# %%
def get_distance(p1, p2):
    dist = math.sqrt((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2)
    return dist

# %%
hospital_locations = pd.read_csv('./datasets/nyc_hospitals.csv')['Location 1']
hospital_latlongs = [(latlong.split('\n')[2]).replace('(', '').replace(')', '').replace(' ', '').split(',') for latlong in list(hospital_locations)]

# %%
hospitals = []
for h in hospital_latlongs:
    longitude = float(h[1])
    latitude = float(h[0])
    #if ((latitude > h_lat_s and latitude < h_lat_n) and
    #        (longitude > h_long_w and longitude < h_long_e)):
    hospitals.append([longitude, latitude, 0])

# %%
for i, hospital in enumerate(hospitals):
    closest_distance = 1000000
    for index, row in tracts.iterrows():
        dist = get_distance((row['long'], row['lat']),
                            (hospital[0], hospital[1]))
        if dist < closest_distance:
            closest_distance = dist
            label = row['label']
    hospitals[i][2] = int(label)

# %%
for i, values in enumerate(hospitals):
    n_long, n_lat, n_label = values
    city_graph.add_node(i,
                        pos=(n_long, n_lat))
    
    color_map.append('orange')

# %%
plt.figure(figsize=(10, 12))

pos=nx.get_node_attributes(city_graph,'pos')
nx.draw(city_graph, pos=pos,
        node_color=color_map, 
        with_labels=False,
        node_size=70)

# %%
subway_locations = pd.read_csv('./datasets/nyc_subway.csv')['the_geom']
subway_latlongs = [s.replace('POINT', '').replace('(', '').replace(')', '').split(' ')[1:3] for s in subway_locations]

# %%
subway = []
for s in subway_latlongs:
    longitude = float(s[0])
    latitude = float(s[1])
    #if ((latitude > h_lat_s and latitude < h_lat_n) and
    #        (longitude > h_long_w and longitude < h_long_e)):
    subway.append([longitude, latitude, 0])

# %%
for i, s in enumerate(subway):
    closest_distance = 1000000
    for index, row in tracts.iterrows():
        dist = get_distance((row['long'], row['lat']),
                            (s[0], s[1]))
        if dist < closest_distance:
            closest_distance = dist
            label = row['label']
    subway[i][2] = int(label)

# %%
school_locations = pd.read_csv('./datasets/nyc_schools.csv')['Location 1']
school_latlongs = [latlong.split('\n')[1].replace('(', '').replace(')', '').replace(' ', '').split(',') for latlong in school_locations[school_locations.notnull()]]

# %%
schools = []
for s in school_latlongs:
    longitude = float(s[1])
    latitude = float(s[0])
    # if ((latitude > nyc_lat_s and latitude < nyc_lat_n) and
    #         (longitude > nyc_long_w and longitude < nyc_long_e)):
    schools.append([longitude, latitude, 0])

# %%
for i, s in enumerate(schools):
    closest_distance = 1000000
    for index, row in tracts.iterrows():
        dist = get_distance((row['long'], row['lat']),
                            (s[0], s[1]))
        if dist < closest_distance:
            closest_distance = dist
            label = row['label']
    schools[i][2] = int(label)

# %%
tract_lats = tracts['lat'].tolist()
tract_longs = tracts['long'].tolist()
tract_labels = tracts['label'].tolist()

# %%
# Remove the components you are interested in seeing
all_nodes = list(zip(tract_longs, tract_lats, tract_labels)) + hospitals + subway + schools

# %%
tract_indices = list(range(0, len(tracts)))
all_indices = list(range(0, len(all_nodes)))
hospital_indices = list(range(len(tracts), len(tracts) + len(hospitals)))
subway_indices = list(range(len(tracts) + len(hospitals), len(tracts) + len(hospitals) + len(subway)))
school_indices = list(range(len(tracts) + len(hospitals) + len(subway), len(tracts) + len(hospitals) + len(subway) + len(schools)))

# %%
len(hospitals), len(hospital_indices)
# Out:
# (78, 78)

# %%
# Creating a graph using NetworkX

# Adding nodes
city_graph = nx.Graph()
color_map = []
for i, values in enumerate(all_nodes):
    n_long, n_lat, n_label = values
    city_graph.add_node(i,
                        pos=(n_long, n_lat))
    
    if n_label == 1:
         color_map.append('purple')
    else:
        color_map.append('lightblue')

# Adding edges
# To observe only one of the networks comment out the unwanted sections
for tract_i in tract_indices+hospital_indices:
    hospital_dict = {}
    for hospital_i in hospital_indices:
        hospital_dict[hospital_i] = get_distance((all_nodes[hospital_i][0], all_nodes[hospital_i][1]),
                                             (all_nodes[tract_i][0], all_nodes[tract_i][1]))
    
    closest2 = sorted(hospital_dict, key=hospital_dict.get, reverse=False)[0:2]
    
    for i in closest2:
        s_lat = all_nodes[i][1]
        s_long = all_nodes[i][0]
        distance = get_distance((all_nodes[tract_i][0], all_nodes[tract_i][1]),
                                (s_long, s_lat))
        city_graph.add_edge(tract_i, i, weight=distance)
        # city_graph.add_edge(tract_i, i)

for tract_i in tract_indices+school_indices:
    school_dict = {}
    for school_i in school_indices:
        school_dict[school_i] = get_distance((all_nodes[school_i][0], all_nodes[school_i][1]),
                                             (all_nodes[tract_i][0], all_nodes[tract_i][1]))
    
    closest2 = sorted(school_dict, key=school_dict.get, reverse=False)[0:2]
    
    for i in closest2:
        s_lat = all_nodes[i][1]
        s_long = all_nodes[i][0]
        distance = get_distance((all_nodes[tract_i][0], all_nodes[tract_i][1]),
                                (s_long, s_lat))
        city_graph.add_edge(tract_i, i, weight=distance)
        # city_graph.add_edge(tract_i, i)

for tract_i in tract_indices+subway_indices:
    subway_dict = {}
    for subway_i in subway_indices:
        subway_dict[subway_i] = get_distance((all_nodes[subway_i][0], all_nodes[subway_i][1]),
                                             (all_nodes[tract_i][0], all_nodes[tract_i][1]))
    
    closest2 = sorted(subway_dict, key=subway_dict.get, reverse=False)[0:2]
    
    for i in closest2:
        s_lat = all_nodes[i][1]
        s_long = all_nodes[i][0]
        distance = get_distance((all_nodes[tract_i][0], all_nodes[tract_i][1]),
                                (s_long, s_lat))
        city_graph.add_edge(tract_i, i, weight=distance)
        # city_graph.add_edge(tract_i, i)

# %%
plt.figure(figsize=(10, 12))

pos=nx.get_node_attributes(city_graph,'pos')
nx.draw(city_graph, pos=pos,
        node_color=color_map, 
        with_labels=False,
        node_size=70)

# %%
tracts
# Out:
#                       id        lat       long  label
# 0     14000US36005000100  40.792936 -73.881207      0
# 1     14000US36005000200  40.803534 -73.860661      0
# 2     14000US36005000400  40.808787 -73.851425      0
# 3     14000US36005001600  40.818848 -73.858076      1
# 4     14000US36005001900  40.800999 -73.909373      1
# ...                  ...        ...        ...    ...
# 2160  14000US36085030302  40.623529 -74.158743      0
# 2161  14000US36085031901  40.630303 -74.163321      1
# 2162  14000US36085031902  40.637921 -74.165570      1
# 2163  14000US36085032300  40.636927 -74.176144      0
# 2164  14000US36085990100  40.525549 -74.108584      0
#
# [2164 rows x 4 columns]

# %%
hospitals_graph = nx.Graph()
nodes = list(zip(tract_longs, tract_lats, tract_labels))+hospitals

for i, values in enumerate(nodes):
    n_long, n_lat, n_label = values
    hospitals_graph.add_node(i, pos=(n_long, n_lat))

# Adding edges
for tract_i,_ in enumerate(nodes):
    hospital_dict = {}
    for hospital_i,_ in enumerate(hospitals):
        hospital_i += len(tract_labels)
        hospital_dict[hospital_i] = get_distance((nodes[hospital_i][0], nodes[hospital_i][1]),
                                             (nodes[tract_i][0], nodes[tract_i][1]))
    
    closest2 = sorted(hospital_dict, key=hospital_dict.get, reverse=False)[0:2]
    
    for i in closest2:
        s_lat = nodes[i][1]
        s_long = nodes[i][0]
        distance = get_distance((nodes[tract_i][0], nodes[tract_i][1]),
                                (s_long, s_lat))
        hospitals_graph.add_edge(tract_i, i, weight=distance)

# %%
subway_graph = nx.Graph()
nodes = list(zip(tract_longs, tract_lats, tract_labels))+subway

for i, values in enumerate(nodes):
    n_long, n_lat, n_label = values
    subway_graph.add_node(i, pos=(n_long, n_lat))

# Adding edges
for tract_i,_ in enumerate(nodes):
    subway_dict = {}
    for subway_i,_ in enumerate(subway):
        subway_i += len(tract_labels)
        subway_dict[subway_i] = get_distance((nodes[subway_i][0], nodes[subway_i][1]),
                                             (nodes[tract_i][0], nodes[tract_i][1]))
    
    closest2 = sorted(subway_dict, key=subway_dict.get, reverse=False)[0:2]
    
    for i in closest2:
        s_lat = nodes[i][1]
        s_long = nodes[i][0]
        distance = get_distance((nodes[tract_i][0], nodes[tract_i][1]),
                                (s_long, s_lat))
        subway_graph.add_edge(tract_i, i, weight=distance)

# %%
schools_graph = nx.Graph()
nodes = list(zip(tract_longs, tract_lats, tract_labels))+schools

for i, values in enumerate(nodes):
    n_long, n_lat, n_label = values
    schools_graph.add_node(i, pos=(n_long, n_lat))

# Adding edges
for tract_i,_ in enumerate(nodes):
    schools_dict = {}
    for school_i,_ in enumerate(schools):
        school_i += len(tract_labels)
        schools_dict[school_i] = get_distance((nodes[school_i][0], nodes[school_i][1]),
                                             (nodes[tract_i][0], nodes[tract_i][1]))
    
    closest2 = sorted(schools_dict, key=schools_dict.get, reverse=False)[0:2]
    
    for i in closest2:
        s_lat = nodes[i][1]
        s_long = nodes[i][0]
        distance = get_distance((nodes[tract_i][0], nodes[tract_i][1]),
                                (s_long, s_lat))
        schools_graph.add_edge(tract_i, i, weight=distance)

# %%
def from_networkx(G, labels):
    G = nx.convert_node_labels_to_integers(G)
    edge_index = torch.LongTensor(list(G.edges)).t().contiguous()
    data = {}
    for i, (_, feat_dict) in enumerate(G.nodes(data=True)):
        for key, value in feat_dict.items():
            data[str(key)] = [value] if i == 0 else data[str(key)] + [value]

    for i, (_, _, feat_dict) in enumerate(G.edges(data=True)):
        for key, value in feat_dict.items():
            data[str(key)] = [value] if i == 0 else data[str(key)] + [value]

    for key, item in data.items():
        try:
            data[key] = torch.tensor(item)
        except ValueError:
            pass
    data['edge_index'] = edge_index.view(2, -1)
    data = torch_geometric.data.Data.from_dict(data)
    data.num_nodes = G.number_of_nodes()
    data.x=torch.from_numpy(np.eye(data.num_nodes))

    all_indices = list(range(0, data.num_nodes))
    random.shuffle(all_indices)
    train_indices = all_indices[0:int(data.num_nodes*0.8)]
    test_indices = all_indices[int(data.num_nodes*0.8):data.num_nodes]

    train_mask = np.array([False]*data.num_nodes)
    train_mask[train_indices] = True
    data.train_mask = torch.from_numpy(train_mask)

    test_mask = np.array([False]*data.num_nodes)
    test_mask[test_indices] = True
    data.test_mask=torch.from_numpy(test_mask)
    
    data.y = torch.from_numpy(labels)
    
    return data

labels = [label for _,_,label in all_nodes]
y = np.asarray(labels)

data = from_networkx(city_graph, y)

# %%
class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        # super(GCN, self).__init__()
        # torch.manual_seed(12345)
        # self.conv1 = GCNConv(data.num_features, hidden_channels)
        # self.conv2 = GCNConv(hidden_channels, 2)

        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GCNConv(data.num_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, 4)
        self.conv3 = GCNConv(4, 2)
        self.classifier = Linear(2, 4)

    def forward(self, x, edge_index):
        # x = self.conv1(x, edge_index)
        # x = x.relu()
        # x = F.dropout(x, p=0.5, training=self.training)
        # x = self.conv2(x, edge_index)
        
        x = self.conv1(x, edge_index)
        x = x.tanh()
        x = self.conv2(x, edge_index)
        x = x.tanh()
        x = self.conv3(x, edge_index)
        x = x.tanh()  # Final GNN embedding space.
        out = self.classifier(x)

        return x

model = GCN(hidden_channels=16)
model.eval()
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(4532, 16)
#   (conv2): GCNConv(16, 4)
#   (conv3): GCNConv(4, 2)
#   (classifier): Linear(in_features=2, out_features=4, bias=True)
# )

# %%
from IPython.display import Javascript  # Restrict height of output cell.
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

model = GCN(hidden_channels=16)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()

def train(dataset):
      model.train()
      optimizer.zero_grad()  # Clear gradients.
      out = model(dataset.x.to(torch.float), dataset.edge_index)  # Perform a single forward pass.
      loss = criterion(out[dataset.train_mask], dataset.y[dataset.train_mask])  # Compute the loss solely based on the training nodes.
      loss.backward()  # Derive gradients.
      optimizer.step()  # Update parameters based on gradients.
      return loss

def test(dataset):
      model.eval()
      out = model(dataset.x.to(torch.float), dataset.edge_index)
      pred = out.argmax(dim=1)  # Use the class with highest probability.
      test_correct = pred[dataset.test_mask] == dataset.y[dataset.test_mask]  # Check against ground-truth labels.
      test_acc = int(test_correct.sum()) / int(dataset.test_mask.sum())  # Derive ratio of correct predictions.
      return test_acc


for epoch in range(1, 500):
    loss = train(data)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
# Out:
# Epoch: 001, Loss: 0.6937
# Epoch: 002, Loss: 0.6340
# Epoch: 003, Loss: 0.5880
# Epoch: 004, Loss: 0.5534
# Epoch: 005, Loss: 0.5262
# Epoch: 006, Loss: 0.5014
# Epoch: 007, Loss: 0.4752
# Epoch: 008, Loss: 0.4466
# Epoch: 009, Loss: 0.4172
# Epoch: 010, Loss: 0.3899
# Epoch: 011, Loss: 0.3672
# Epoch: 012, Loss: 0.3493
# Epoch: 013, Loss: 0.3353
# Epoch: 014, Loss: 0.3237
# Epoch: 015, Loss: 0.3132
# Epoch: 016, Loss: 0.3031
# Epoch: 017, Loss: 0.2932
# Epoch: 018, Loss: 0.2837
# Epoch: 019, Loss: 0.2751
# Epoch: 020, Loss: 0.2678
# Epoch: 021, Loss: 0.2620
# Epoch: 022, Loss: 0.2573
# Epoch: 023, Loss: 0.2534
# Epoch: 024, Loss: 0.2496
# Epoch: 025, Loss: 0.2458
# Epoch: 026, Loss: 0.2420
# Epoch: 027, Loss: 0.2384
# Epoch: 028, Loss: 0.2355
# Epoch: 029, Loss: 0.2331
# Epoch: 030, Loss: 0.2311
# Epoch: 031, Loss: 0.2291
# Epoch: 032, Loss: 0.2271
# Epoch: 033, Loss: 0.2252
# Epoch: 034, Loss: 0.2235
# Epoch: 035, Loss: 0.2219
# Epoch: 036, Loss: 0.2202
# Epoch: 037, Loss: 0.2184
# Epoch: 038, Loss: 0.2167
# Epoch: 039, Loss: 0.2152
# Epoch: 040, Loss: 0.2139
# Epoch: 041, Loss: 0.2124
# Epoch: 042, Loss: 0.2110
# Epoch: 043, Loss: 0.2098
# Epoch: 044, Loss: 0.2086
# Epoch: 045, Loss: 0.2073
# Epoch: 046, Loss: 0.2060
# Epoch: 047, Loss: 0.2048
# Epoch: 048, Loss: 0.2037
# Epoch: 049, Loss: 0.2026
# Epoch: 050, Loss: 0.2016
# Epoch: 051, Loss: 0.2006
# Epoch: 052, Loss: 0.1996
# Epoch: 053, Loss: 0.1986
# Epoch: 054, Loss: 0.1977
# Epoch: 055, Loss: 0.1967
# Epoch: 056, Loss: 0.1959
# Epoch: 057, Loss: 0.1951
# Epoch: 058, Loss: 0.1942
# Epoch: 059, Loss: 0.1934
# Epoch: 060, Loss: 0.1926
# Epoch: 061, Loss: 0.1918
# Epoch: 062, Loss: 0.1911
# Epoch: 063, Loss: 0.1903
# Epoch: 064, Loss: 0.1896
# Epoch: 065, Loss: 0.1889
# Epoch: 066, Loss: 0.1883
# Epoch: 067, Loss: 0.1876
# Epoch: 068, Loss: 0.1869
# Epoch: 069, Loss: 0.1863
# Epoch: 070, Loss: 0.1856
# Epoch: 071, Loss: 0.1851
# Epoch: 072, Loss: 0.1845
# Epoch: 073, Loss: 0.1839
# Epoch: 074, Loss: 0.1834
# Epoch: 075, Loss: 0.1829
# Epoch: 076, Loss: 0.1824
# Epoch: 077, Loss: 0.1819
# Epoch: 078, Loss: 0.1815
# Epoch: 079, Loss: 0.1810
# Epoch: 080, Loss: 0.1806
# Epoch: 081, Loss: 0.1802
# Epoch: 082, Loss: 0.1798
# Epoch: 083, Loss: 0.1793
# Epoch: 084, Loss: 0.1789
# Epoch: 085, Loss: 0.1785
# Epoch: 086, Loss: 0.1782
# Epoch: 087, Loss: 0.1778
# Epoch: 088, Loss: 0.1774
# Epoch: 089, Loss: 0.1771
# Epoch: 090, Loss: 0.1767
# Epoch: 091, Loss: 0.1763
# Epoch: 092, Loss: 0.1760
# Epoch: 093, Loss: 0.1757
# Epoch: 094, Loss: 0.1753
# Epoch: 095, Loss: 0.1750
# Epoch: 096, Loss: 0.1747
# Epoch: 097, Loss: 0.1744
# Epoch: 098, Loss: 0.1741
# Epoch: 099, Loss: 0.1738
# Epoch: 100, Loss: 0.1735
# Epoch: 101, Loss: 0.1732
# Epoch: 102, Loss: 0.1729
# Epoch: 103, Loss: 0.1727
# Epoch: 104, Loss: 0.1724
# Epoch: 105, Loss: 0.1721
# Epoch: 106, Loss: 0.1719
# Epoch: 107, Loss: 0.1717
# Epoch: 108, Loss: 0.1714
# Epoch: 109, Loss: 0.1712
# Epoch: 110, Loss: 0.1709
# Epoch: 111, Loss: 0.1707
# Epoch: 112, Loss: 0.1705
# Epoch: 113, Loss: 0.1703
# Epoch: 114, Loss: 0.1700
# Epoch: 115, Loss: 0.1698
# Epoch: 116, Loss: 0.1696
# Epoch: 117, Loss: 0.1694
# Epoch: 118, Loss: 0.1692
# Epoch: 119, Loss: 0.1690
# Epoch: 120, Loss: 0.1688
# Epoch: 121, Loss: 0.1686
# Epoch: 122, Loss: 0.1684
# Epoch: 123, Loss: 0.1682
# Epoch: 124, Loss: 0.1681
# Epoch: 125, Loss: 0.1679
# Epoch: 126, Loss: 0.1678
# Epoch: 127, Loss: 0.1678
# Epoch: 128, Loss: 0.1681
# Epoch: 129, Loss: 0.1681
# Epoch: 130, Loss: 0.1673
# Epoch: 131, Loss: 0.1668
# Epoch: 132, Loss: 0.1670
# Epoch: 133, Loss: 0.1670
# Epoch: 134, Loss: 0.1664
# Epoch: 135, Loss: 0.1661
# Epoch: 136, Loss: 0.1664
# Epoch: 137, Loss: 0.1663
# Epoch: 138, Loss: 0.1657
# Epoch: 139, Loss: 0.1657
# Epoch: 140, Loss: 0.1659
# Epoch: 141, Loss: 0.1654
# Epoch: 142, Loss: 0.1652
# Epoch: 143, Loss: 0.1653
# Epoch: 144, Loss: 0.1651
# Epoch: 145, Loss: 0.1648
# Epoch: 146, Loss: 0.1648
# Epoch: 147, Loss: 0.1648
# Epoch: 148, Loss: 0.1645
# Epoch: 149, Loss: 0.1643
# Epoch: 150, Loss: 0.1644
# Epoch: 151, Loss: 0.1643
# Epoch: 152, Loss: 0.1641
# Epoch: 153, Loss: 0.1639
# Epoch: 154, Loss: 0.1638
# Epoch: 155, Loss: 0.1638
# Epoch: 156, Loss: 0.1636
# Epoch: 157, Loss: 0.1635
# Epoch: 158, Loss: 0.1633
# Epoch: 159, Loss: 0.1633
# Epoch: 160, Loss: 0.1632
# Epoch: 161, Loss: 0.1630
# Epoch: 162, Loss: 0.1629
# Epoch: 163, Loss: 0.1628
# Epoch: 164, Loss: 0.1628
# Epoch: 165, Loss: 0.1627
# Epoch: 166, Loss: 0.1626
# Epoch: 167, Loss: 0.1624
# Epoch: 168, Loss: 0.1623
# Epoch: 169, Loss: 0.1623
# Epoch: 170, Loss: 0.1623
# Epoch: 171, Loss: 0.1622
# Epoch: 172, Loss: 0.1620
# Epoch: 173, Loss: 0.1619
# Epoch: 174, Loss: 0.1618
# Epoch: 175, Loss: 0.1617
# Epoch: 176, Loss: 0.1616
# Epoch: 177, Loss: 0.1616
# Epoch: 178, Loss: 0.1615
# Epoch: 179, Loss: 0.1615
# Epoch: 180, Loss: 0.1614
# Epoch: 181, Loss: 0.1613
# Epoch: 182, Loss: 0.1612
# Epoch: 183, Loss: 0.1611
# Epoch: 184, Loss: 0.1610
# Epoch: 185, Loss: 0.1609
# Epoch: 186, Loss: 0.1609
# Epoch: 187, Loss: 0.1608
# Epoch: 188, Loss: 0.1607
# Epoch: 189, Loss: 0.1607
# Epoch: 190, Loss: 0.1606
# Epoch: 191, Loss: 0.1606
# Epoch: 192, Loss: 0.1606
# Epoch: 193, Loss: 0.1607
# Epoch: 194, Loss: 0.1610
# Epoch: 195, Loss: 0.1612
# Epoch: 196, Loss: 0.1613
# Epoch: 197, Loss: 0.1604
# Epoch: 198, Loss: 0.1599
# Epoch: 199, Loss: 0.1600
# Epoch: 200, Loss: 0.1601
# Epoch: 201, Loss: 0.1602
# Epoch: 202, Loss: 0.1600
# Epoch: 203, Loss: 0.1597
# Epoch: 204, Loss: 0.1599
# Epoch: 205, Loss: 0.1597
# Epoch: 206, Loss: 0.1596
# Epoch: 207, Loss: 0.1598
# Epoch: 208, Loss: 0.1595
# Epoch: 209, Loss: 0.1597
# Epoch: 210, Loss: 0.1597
# Epoch: 211, Loss: 0.1596
# Epoch: 212, Loss: 0.1592
# Epoch: 213, Loss: 0.1593
# Epoch: 214, Loss: 0.1591
# Epoch: 215, Loss: 0.1591
# Epoch: 216, Loss: 0.1591
# Epoch: 217, Loss: 0.1590
# Epoch: 218, Loss: 0.1590
# Epoch: 219, Loss: 0.1589
# Epoch: 220, Loss: 0.1589
# Epoch: 221, Loss: 0.1588
# Epoch: 222, Loss: 0.1588
# Epoch: 223, Loss: 0.1587
# Epoch: 224, Loss: 0.1587
# Epoch: 225, Loss: 0.1586
# Epoch: 226, Loss: 0.1586
# Epoch: 227, Loss: 0.1586
# Epoch: 228, Loss: 0.1585
# Epoch: 229, Loss: 0.1585
# Epoch: 230, Loss: 0.1584
# Epoch: 231, Loss: 0.1584
# Epoch: 232, Loss: 0.1583
# Epoch: 233, Loss: 0.1583
# Epoch: 234, Loss: 0.1582
# Epoch: 235, Loss: 0.1582
# Epoch: 236, Loss: 0.1582
# Epoch: 237, Loss: 0.1583
# Epoch: 238, Loss: 0.1585
# Epoch: 239, Loss: 0.1587
# Epoch: 240, Loss: 0.1592
# Epoch: 241, Loss: 0.1591
# Epoch: 242, Loss: 0.1585
# Epoch: 243, Loss: 0.1577
# Epoch: 244, Loss: 0.1579
# Epoch: 245, Loss: 0.1589
# Epoch: 246, Loss: 0.1588
# Epoch: 247, Loss: 0.1577
# Epoch: 248, Loss: 0.1576
# Epoch: 249, Loss: 0.1583
# Epoch: 250, Loss: 0.1585
# Epoch: 251, Loss: 0.1577
# Epoch: 252, Loss: 0.1579
# Epoch: 253, Loss: 0.1584
# Epoch: 254, Loss: 0.1577
# Epoch: 255, Loss: 0.1574
# Epoch: 256, Loss: 0.1576
# Epoch: 257, Loss: 0.1575
# Epoch: 258, Loss: 0.1573
# Epoch: 259, Loss: 0.1575
# Epoch: 260, Loss: 0.1577
# Epoch: 261, Loss: 0.1575
# Epoch: 262, Loss: 0.1573
# Epoch: 263, Loss: 0.1575
# Epoch: 264, Loss: 0.1575
# Epoch: 265, Loss: 0.1574
# Epoch: 266, Loss: 0.1572
# Epoch: 267, Loss: 0.1572
# Epoch: 268, Loss: 0.1572
# Epoch: 269, Loss: 0.1571
# Epoch: 270, Loss: 0.1571
# Epoch: 271, Loss: 0.1570
# Epoch: 272, Loss: 0.1570
# Epoch: 273, Loss: 0.1570
# Epoch: 274, Loss: 0.1570
# Epoch: 275, Loss: 0.1569
# Epoch: 276, Loss: 0.1569
# Epoch: 277, Loss: 0.1569
# Epoch: 278, Loss: 0.1569
# Epoch: 279, Loss: 0.1568
# Epoch: 280, Loss: 0.1568
# Epoch: 281, Loss: 0.1568
# Epoch: 282, Loss: 0.1568
# Epoch: 283, Loss: 0.1567
# Epoch: 284, Loss: 0.1567
# Epoch: 285, Loss: 0.1567
# Epoch: 286, Loss: 0.1566
# Epoch: 287, Loss: 0.1566
# Epoch: 288, Loss: 0.1566
# Epoch: 289, Loss: 0.1566
# Epoch: 290, Loss: 0.1565
# Epoch: 291, Loss: 0.1565
# Epoch: 292, Loss: 0.1565
# Epoch: 293, Loss: 0.1565
# Epoch: 294, Loss: 0.1564
# Epoch: 295, Loss: 0.1564
# Epoch: 296, Loss: 0.1564
# Epoch: 297, Loss: 0.1564
# Epoch: 298, Loss: 0.1563
# Epoch: 299, Loss: 0.1563
# Epoch: 300, Loss: 0.1563
# Epoch: 301, Loss: 0.1563
# Epoch: 302, Loss: 0.1562
# Epoch: 303, Loss: 0.1562
# Epoch: 304, Loss: 0.1562
# Epoch: 305, Loss: 0.1562
# Epoch: 306, Loss: 0.1561
# Epoch: 307, Loss: 0.1561
# Epoch: 308, Loss: 0.1561
# Epoch: 309, Loss: 0.1561
# Epoch: 310, Loss: 0.1561
# Epoch: 311, Loss: 0.1560
# Epoch: 312, Loss: 0.1560
# Epoch: 313, Loss: 0.1560
# Epoch: 314, Loss: 0.1560
# Epoch: 315, Loss: 0.1560
# Epoch: 316, Loss: 0.1559
# Epoch: 317, Loss: 0.1559
# Epoch: 318, Loss: 0.1559
# Epoch: 319, Loss: 0.1559
# Epoch: 320, Loss: 0.1559
# Epoch: 321, Loss: 0.1558
# Epoch: 322, Loss: 0.1558
# Epoch: 323, Loss: 0.1558
# Epoch: 324, Loss: 0.1558
# Epoch: 325, Loss: 0.1558
# Epoch: 326, Loss: 0.1557
# Epoch: 327, Loss: 0.1557
# Epoch: 328, Loss: 0.1557
# Epoch: 329, Loss: 0.1557
# Epoch: 330, Loss: 0.1557
# Epoch: 331, Loss: 0.1557
# Epoch: 332, Loss: 0.1556
# Epoch: 333, Loss: 0.1556
# Epoch: 334, Loss: 0.1556
# Epoch: 335, Loss: 0.1556
# Epoch: 336, Loss: 0.1556
# Epoch: 337, Loss: 0.1555
# Epoch: 338, Loss: 0.1555
# Epoch: 339, Loss: 0.1555
# Epoch: 340, Loss: 0.1555
# Epoch: 341, Loss: 0.1555
# Epoch: 342, Loss: 0.1555
# Epoch: 343, Loss: 0.1555
# Epoch: 344, Loss: 0.1555
# Epoch: 345, Loss: 0.1555
# Epoch: 346, Loss: 0.1555
# Epoch: 347, Loss: 0.1557
# Epoch: 348, Loss: 0.1560
# Epoch: 349, Loss: 0.1563
# Epoch: 350, Loss: 0.1570
# Epoch: 351, Loss: 0.1563
# Epoch: 352, Loss: 0.1552
# Epoch: 353, Loss: 0.1548
# Epoch: 354, Loss: 0.1558
# Epoch: 355, Loss: 0.1577
# Epoch: 356, Loss: 0.1567
# Epoch: 357, Loss: 0.1549
# Epoch: 358, Loss: 0.1555
# Epoch: 359, Loss: 0.1562
# Epoch: 360, Loss: 0.1567
# Epoch: 361, Loss: 0.1556
# Epoch: 362, Loss: 0.1558
# Epoch: 363, Loss: 0.1561
# Epoch: 364, Loss: 0.1550
# Epoch: 365, Loss: 0.1554
# Epoch: 366, Loss: 0.1558
# Epoch: 367, Loss: 0.1553
# Epoch: 368, Loss: 0.1553
# Epoch: 369, Loss: 0.1555
# Epoch: 370, Loss: 0.1551
# Epoch: 371, Loss: 0.1551
# Epoch: 372, Loss: 0.1554
# Epoch: 373, Loss: 0.1553
# Epoch: 374, Loss: 0.1553
# Epoch: 375, Loss: 0.1553
# Epoch: 376, Loss: 0.1551
# Epoch: 377, Loss: 0.1552
# Epoch: 378, Loss: 0.1552
# Epoch: 379, Loss: 0.1551
# Epoch: 380, Loss: 0.1552
# Epoch: 381, Loss: 0.1552
# Epoch: 382, Loss: 0.1550
# Epoch: 383, Loss: 0.1550
# Epoch: 384, Loss: 0.1551
# Epoch: 385, Loss: 0.1550
# Epoch: 386, Loss: 0.1550
# Epoch: 387, Loss: 0.1550
# Epoch: 388, Loss: 0.1549
# Epoch: 389, Loss: 0.1549
# Epoch: 390, Loss: 0.1549
# Epoch: 391, Loss: 0.1549
# Epoch: 392, Loss: 0.1549
# Epoch: 393, Loss: 0.1548
# Epoch: 394, Loss: 0.1548
# Epoch: 395, Loss: 0.1548
# Epoch: 396, Loss: 0.1548
# Epoch: 397, Loss: 0.1548
# Epoch: 398, Loss: 0.1548
# Epoch: 399, Loss: 0.1547
# Epoch: 400, Loss: 0.1547
# Epoch: 401, Loss: 0.1547
# Epoch: 402, Loss: 0.1547
# Epoch: 403, Loss: 0.1547
# Epoch: 404, Loss: 0.1547
# Epoch: 405, Loss: 0.1547
# Epoch: 406, Loss: 0.1547
# Epoch: 407, Loss: 0.1547
# Epoch: 408, Loss: 0.1546
# Epoch: 409, Loss: 0.1546
# Epoch: 410, Loss: 0.1546
# Epoch: 411, Loss: 0.1546
# Epoch: 412, Loss: 0.1546
# Epoch: 413, Loss: 0.1546
# Epoch: 414, Loss: 0.1545
# Epoch: 415, Loss: 0.1545
# Epoch: 416, Loss: 0.1545
# Epoch: 417, Loss: 0.1545
# Epoch: 418, Loss: 0.1545
# Epoch: 419, Loss: 0.1545
# Epoch: 420, Loss: 0.1545
# Epoch: 421, Loss: 0.1545
# Epoch: 422, Loss: 0.1545
# Epoch: 423, Loss: 0.1545
# Epoch: 424, Loss: 0.1544
# Epoch: 425, Loss: 0.1544
# Epoch: 426, Loss: 0.1544
# Epoch: 427, Loss: 0.1544
# Epoch: 428, Loss: 0.1544
# Epoch: 429, Loss: 0.1544
# Epoch: 430, Loss: 0.1544
# Epoch: 431, Loss: 0.1544
# Epoch: 432, Loss: 0.1544
# Epoch: 433, Loss: 0.1543
# Epoch: 434, Loss: 0.1543
# Epoch: 435, Loss: 0.1543
# Epoch: 436, Loss: 0.1543
# Epoch: 437, Loss: 0.1543
# Epoch: 438, Loss: 0.1543
# Epoch: 439, Loss: 0.1543
# Epoch: 440, Loss: 0.1543
# Epoch: 441, Loss: 0.1543
# Epoch: 442, Loss: 0.1543
# Epoch: 443, Loss: 0.1542
# Epoch: 444, Loss: 0.1542
# Epoch: 445, Loss: 0.1542
# Epoch: 446, Loss: 0.1542
# Epoch: 447, Loss: 0.1542
# Epoch: 448, Loss: 0.1542
# Epoch: 449, Loss: 0.1542
# Epoch: 450, Loss: 0.1542
# Epoch: 451, Loss: 0.1542
# Epoch: 452, Loss: 0.1542
# Epoch: 453, Loss: 0.1541
# Epoch: 454, Loss: 0.1541
# Epoch: 455, Loss: 0.1541
# Epoch: 456, Loss: 0.1541
# Epoch: 457, Loss: 0.1541
# Epoch: 458, Loss: 0.1541
# Epoch: 459, Loss: 0.1541
# Epoch: 460, Loss: 0.1541
# Epoch: 461, Loss: 0.1541
# Epoch: 462, Loss: 0.1540
# Epoch: 463, Loss: 0.1540
# Epoch: 464, Loss: 0.1540
# Epoch: 465, Loss: 0.1540
# Epoch: 466, Loss: 0.1540
# Epoch: 467, Loss: 0.1540
# Epoch: 468, Loss: 0.1540
# Epoch: 469, Loss: 0.1540
# Epoch: 470, Loss: 0.1540
# Epoch: 471, Loss: 0.1540
# Epoch: 472, Loss: 0.1539
# Epoch: 473, Loss: 0.1539
# Epoch: 474, Loss: 0.1539
# Epoch: 475, Loss: 0.1539
# Epoch: 476, Loss: 0.1539
# Epoch: 477, Loss: 0.1539
# Epoch: 478, Loss: 0.1539
# Epoch: 479, Loss: 0.1539
# Epoch: 480, Loss: 0.1539
# Epoch: 481, Loss: 0.1539
# Epoch: 482, Loss: 0.1539
# Epoch: 483, Loss: 0.1538
# Epoch: 484, Loss: 0.1538
# Epoch: 485, Loss: 0.1538
# Epoch: 486, Loss: 0.1538
# Epoch: 487, Loss: 0.1538
# Epoch: 488, Loss: 0.1538
# Epoch: 489, Loss: 0.1538
# Epoch: 490, Loss: 0.1538
# Epoch: 491, Loss: 0.1538
# Epoch: 492, Loss: 0.1538
# Epoch: 493, Loss: 0.1538
# Epoch: 494, Loss: 0.1537
# Epoch: 495, Loss: 0.1537
# Epoch: 496, Loss: 0.1537
# Epoch: 497, Loss: 0.1537
# Epoch: 498, Loss: 0.1537
# Epoch: 499, Loss: 0.1537

# %%
out = model(data.x.to(torch.float), data.edge_index)

# %%
test_acc = test(data)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# Test Accuracy: 0.8346

# %%
data = from_networkx(hospitals_graph, y[tract_indices+hospital_indices])
model = GCN(hidden_channels=16)
print(model)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()

for epoch in range(1, 500):
    loss = train(data)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')

out = model(data.x.to(torch.float), data.edge_index)
test_acc = test(data)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# GCN(
#   (conv1): GCNConv(2242, 16)
#   (conv2): GCNConv(16, 4)
#   (conv3): GCNConv(4, 2)
#   (classifier): Linear(in_features=2, out_features=4, bias=True)
# )
# Epoch: 001, Loss: 0.6931
# Epoch: 002, Loss: 0.6518
# Epoch: 003, Loss: 0.6128
# Epoch: 004, Loss: 0.5750
# Epoch: 005, Loss: 0.5399
# Epoch: 006, Loss: 0.5087
# Epoch: 007, Loss: 0.4819
# Epoch: 008, Loss: 0.4590
# Epoch: 009, Loss: 0.4385
# Epoch: 010, Loss: 0.4188
# Epoch: 011, Loss: 0.3984
# Epoch: 012, Loss: 0.3767
# Epoch: 013, Loss: 0.3538
# Epoch: 014, Loss: 0.3306
# Epoch: 015, Loss: 0.3088
# Epoch: 016, Loss: 0.2896
# Epoch: 017, Loss: 0.2737
# Epoch: 018, Loss: 0.2612
# Epoch: 019, Loss: 0.2514
# Epoch: 020, Loss: 0.2434
# Epoch: 021, Loss: 0.2365
# Epoch: 022, Loss: 0.2302
# Epoch: 023, Loss: 0.2241
# Epoch: 024, Loss: 0.2182
# Epoch: 025, Loss: 0.2125
# Epoch: 026, Loss: 0.2073
# Epoch: 027, Loss: 0.2026
# Epoch: 028, Loss: 0.1985
# Epoch: 029, Loss: 0.1953
# Epoch: 030, Loss: 0.1930
# Epoch: 031, Loss: 0.1913
# Epoch: 032, Loss: 0.1900
# Epoch: 033, Loss: 0.1889
# Epoch: 034, Loss: 0.1878
# Epoch: 035, Loss: 0.1867
# Epoch: 036, Loss: 0.1858
# Epoch: 037, Loss: 0.1850
# Epoch: 038, Loss: 0.1843
# Epoch: 039, Loss: 0.1837
# Epoch: 040, Loss: 0.1832
# Epoch: 041, Loss: 0.1826
# Epoch: 042, Loss: 0.1819
# Epoch: 043, Loss: 0.1811
# Epoch: 044, Loss: 0.1801
# Epoch: 045, Loss: 0.1791
# Epoch: 046, Loss: 0.1779
# Epoch: 047, Loss: 0.1768
# Epoch: 048, Loss: 0.1756
# Epoch: 049, Loss: 0.1744
# Epoch: 050, Loss: 0.1733
# Epoch: 051, Loss: 0.1721
# Epoch: 052, Loss: 0.1710
# Epoch: 053, Loss: 0.1700
# Epoch: 054, Loss: 0.1691
# Epoch: 055, Loss: 0.1683
# Epoch: 056, Loss: 0.1676
# Epoch: 057, Loss: 0.1669
# Epoch: 058, Loss: 0.1663
# Epoch: 059, Loss: 0.1658
# Epoch: 060, Loss: 0.1653
# Epoch: 061, Loss: 0.1650
# Epoch: 062, Loss: 0.1646
# Epoch: 063, Loss: 0.1643
# Epoch: 064, Loss: 0.1640
# Epoch: 065, Loss: 0.1637
# Epoch: 066, Loss: 0.1634
# Epoch: 067, Loss: 0.1632
# Epoch: 068, Loss: 0.1629
# Epoch: 069, Loss: 0.1626
# Epoch: 070, Loss: 0.1623
# Epoch: 071, Loss: 0.1619
# Epoch: 072, Loss: 0.1616
# Epoch: 073, Loss: 0.1613
# Epoch: 074, Loss: 0.1610
# Epoch: 075, Loss: 0.1606
# Epoch: 076, Loss: 0.1603
# Epoch: 077, Loss: 0.1599
# Epoch: 078, Loss: 0.1596
# Epoch: 079, Loss: 0.1593
# Epoch: 080, Loss: 0.1591
# Epoch: 081, Loss: 0.1588
# Epoch: 082, Loss: 0.1585
# Epoch: 083, Loss: 0.1583
# Epoch: 084, Loss: 0.1581
# Epoch: 085, Loss: 0.1579
# Epoch: 086, Loss: 0.1577
# Epoch: 087, Loss: 0.1576
# Epoch: 088, Loss: 0.1574
# Epoch: 089, Loss: 0.1572
# Epoch: 090, Loss: 0.1571
# Epoch: 091, Loss: 0.1569
# Epoch: 092, Loss: 0.1568
# Epoch: 093, Loss: 0.1566
# Epoch: 094, Loss: 0.1565
# Epoch: 095, Loss: 0.1563
# Epoch: 096, Loss: 0.1561
# Epoch: 097, Loss: 0.1560
# Epoch: 098, Loss: 0.1558
# Epoch: 099, Loss: 0.1557
# Epoch: 100, Loss: 0.1555
# Epoch: 101, Loss: 0.1554
# Epoch: 102, Loss: 0.1552
# Epoch: 103, Loss: 0.1551
# Epoch: 104, Loss: 0.1550
# Epoch: 105, Loss: 0.1549
# Epoch: 106, Loss: 0.1547
# Epoch: 107, Loss: 0.1546
# Epoch: 108, Loss: 0.1545
# Epoch: 109, Loss: 0.1544
# Epoch: 110, Loss: 0.1543
# Epoch: 111, Loss: 0.1542
# Epoch: 112, Loss: 0.1541
# Epoch: 113, Loss: 0.1540
# Epoch: 114, Loss: 0.1539
# Epoch: 115, Loss: 0.1538
# Epoch: 116, Loss: 0.1537
# Epoch: 117, Loss: 0.1536
# Epoch: 118, Loss: 0.1535
# Epoch: 119, Loss: 0.1534
# Epoch: 120, Loss: 0.1533
# Epoch: 121, Loss: 0.1532
# Epoch: 122, Loss: 0.1531
# Epoch: 123, Loss: 0.1530
# Epoch: 124, Loss: 0.1529
# Epoch: 125, Loss: 0.1529
# Epoch: 126, Loss: 0.1528
# Epoch: 127, Loss: 0.1527
# Epoch: 128, Loss: 0.1526
# Epoch: 129, Loss: 0.1526
# Epoch: 130, Loss: 0.1525
# Epoch: 131, Loss: 0.1524
# Epoch: 132, Loss: 0.1523
# Epoch: 133, Loss: 0.1523
# Epoch: 134, Loss: 0.1522
# Epoch: 135, Loss: 0.1521
# Epoch: 136, Loss: 0.1521
# Epoch: 137, Loss: 0.1520
# Epoch: 138, Loss: 0.1519
# Epoch: 139, Loss: 0.1519
# Epoch: 140, Loss: 0.1518
# Epoch: 141, Loss: 0.1517
# Epoch: 142, Loss: 0.1517
# Epoch: 143, Loss: 0.1516
# Epoch: 144, Loss: 0.1516
# Epoch: 145, Loss: 0.1515
# Epoch: 146, Loss: 0.1515
# Epoch: 147, Loss: 0.1514
# Epoch: 148, Loss: 0.1513
# Epoch: 149, Loss: 0.1513
# Epoch: 150, Loss: 0.1512
# Epoch: 151, Loss: 0.1512
# Epoch: 152, Loss: 0.1511
# Epoch: 153, Loss: 0.1511
# Epoch: 154, Loss: 0.1510
# Epoch: 155, Loss: 0.1510
# Epoch: 156, Loss: 0.1509
# Epoch: 157, Loss: 0.1509
# Epoch: 158, Loss: 0.1508
# Epoch: 159, Loss: 0.1508
# Epoch: 160, Loss: 0.1507
# Epoch: 161, Loss: 0.1507
# Epoch: 162, Loss: 0.1507
# Epoch: 163, Loss: 0.1506
# Epoch: 164, Loss: 0.1506
# Epoch: 165, Loss: 0.1505
# Epoch: 166, Loss: 0.1505
# Epoch: 167, Loss: 0.1504
# Epoch: 168, Loss: 0.1504
# Epoch: 169, Loss: 0.1504
# Epoch: 170, Loss: 0.1503
# Epoch: 171, Loss: 0.1503
# Epoch: 172, Loss: 0.1503
# Epoch: 173, Loss: 0.1502
# Epoch: 174, Loss: 0.1502
# Epoch: 175, Loss: 0.1501
# Epoch: 176, Loss: 0.1501
# Epoch: 177, Loss: 0.1501
# Epoch: 178, Loss: 0.1500
# Epoch: 179, Loss: 0.1500
# Epoch: 180, Loss: 0.1500
# Epoch: 181, Loss: 0.1499
# Epoch: 182, Loss: 0.1499
# Epoch: 183, Loss: 0.1499
# Epoch: 184, Loss: 0.1498
# Epoch: 185, Loss: 0.1498
# Epoch: 186, Loss: 0.1498
# Epoch: 187, Loss: 0.1497
# Epoch: 188, Loss: 0.1497
# Epoch: 189, Loss: 0.1497
# Epoch: 190, Loss: 0.1496
# Epoch: 191, Loss: 0.1496
# Epoch: 192, Loss: 0.1496
# Epoch: 193, Loss: 0.1496
# Epoch: 194, Loss: 0.1495
# Epoch: 195, Loss: 0.1495
# Epoch: 196, Loss: 0.1495
# Epoch: 197, Loss: 0.1494
# Epoch: 198, Loss: 0.1494
# Epoch: 199, Loss: 0.1494
# Epoch: 200, Loss: 0.1494
# Epoch: 201, Loss: 0.1493
# Epoch: 202, Loss: 0.1493
# Epoch: 203, Loss: 0.1493
# Epoch: 204, Loss: 0.1493
# Epoch: 205, Loss: 0.1492
# Epoch: 206, Loss: 0.1492
# Epoch: 207, Loss: 0.1492
# Epoch: 208, Loss: 0.1492
# Epoch: 209, Loss: 0.1491
# Epoch: 210, Loss: 0.1491
# Epoch: 211, Loss: 0.1491
# Epoch: 212, Loss: 0.1491
# Epoch: 213, Loss: 0.1490
# Epoch: 214, Loss: 0.1490
# Epoch: 215, Loss: 0.1490
# Epoch: 216, Loss: 0.1490
# Epoch: 217, Loss: 0.1490
# Epoch: 218, Loss: 0.1489
# Epoch: 219, Loss: 0.1489
# Epoch: 220, Loss: 0.1489
# Epoch: 221, Loss: 0.1489
# Epoch: 222, Loss: 0.1488
# Epoch: 223, Loss: 0.1488
# Epoch: 224, Loss: 0.1488
# Epoch: 225, Loss: 0.1488
# Epoch: 226, Loss: 0.1488
# Epoch: 227, Loss: 0.1487
# Epoch: 228, Loss: 0.1487
# Epoch: 229, Loss: 0.1487
# Epoch: 230, Loss: 0.1487
# Epoch: 231, Loss: 0.1487
# Epoch: 232, Loss: 0.1487
# Epoch: 233, Loss: 0.1486
# Epoch: 234, Loss: 0.1486
# Epoch: 235, Loss: 0.1486
# Epoch: 236, Loss: 0.1486
# Epoch: 237, Loss: 0.1486
# Epoch: 238, Loss: 0.1485
# Epoch: 239, Loss: 0.1485
# Epoch: 240, Loss: 0.1485
# Epoch: 241, Loss: 0.1485
# Epoch: 242, Loss: 0.1485
# Epoch: 243, Loss: 0.1485
# Epoch: 244, Loss: 0.1484
# Epoch: 245, Loss: 0.1484
# Epoch: 246, Loss: 0.1484
# Epoch: 247, Loss: 0.1484
# Epoch: 248, Loss: 0.1484
# Epoch: 249, Loss: 0.1484
# Epoch: 250, Loss: 0.1483
# Epoch: 251, Loss: 0.1483
# Epoch: 252, Loss: 0.1483
# Epoch: 253, Loss: 0.1483
# Epoch: 254, Loss: 0.1483
# Epoch: 255, Loss: 0.1483
# Epoch: 256, Loss: 0.1483
# Epoch: 257, Loss: 0.1482
# Epoch: 258, Loss: 0.1482
# Epoch: 259, Loss: 0.1482
# Epoch: 260, Loss: 0.1482
# Epoch: 261, Loss: 0.1482
# Epoch: 262, Loss: 0.1482
# Epoch: 263, Loss: 0.1482
# Epoch: 264, Loss: 0.1481
# Epoch: 265, Loss: 0.1481
# Epoch: 266, Loss: 0.1481
# Epoch: 267, Loss: 0.1481
# Epoch: 268, Loss: 0.1481
# Epoch: 269, Loss: 0.1481
# Epoch: 270, Loss: 0.1481
# Epoch: 271, Loss: 0.1481
# Epoch: 272, Loss: 0.1480
# Epoch: 273, Loss: 0.1480
# Epoch: 274, Loss: 0.1480
# Epoch: 275, Loss: 0.1480
# Epoch: 276, Loss: 0.1480
# Epoch: 277, Loss: 0.1480
# Epoch: 278, Loss: 0.1480
# Epoch: 279, Loss: 0.1480
# Epoch: 280, Loss: 0.1479
# Epoch: 281, Loss: 0.1479
# Epoch: 282, Loss: 0.1479
# Epoch: 283, Loss: 0.1479
# Epoch: 284, Loss: 0.1479
# Epoch: 285, Loss: 0.1479
# Epoch: 286, Loss: 0.1479
# Epoch: 287, Loss: 0.1479
# Epoch: 288, Loss: 0.1479
# Epoch: 289, Loss: 0.1478
# Epoch: 290, Loss: 0.1478
# Epoch: 291, Loss: 0.1478
# Epoch: 292, Loss: 0.1478
# Epoch: 293, Loss: 0.1478
# Epoch: 294, Loss: 0.1478
# Epoch: 295, Loss: 0.1478
# Epoch: 296, Loss: 0.1478
# Epoch: 297, Loss: 0.1478
# Epoch: 298, Loss: 0.1478
# Epoch: 299, Loss: 0.1477
# Epoch: 300, Loss: 0.1477
# Epoch: 301, Loss: 0.1477
# Epoch: 302, Loss: 0.1477
# Epoch: 303, Loss: 0.1477
# Epoch: 304, Loss: 0.1477
# Epoch: 305, Loss: 0.1477
# Epoch: 306, Loss: 0.1477
# Epoch: 307, Loss: 0.1477
# Epoch: 308, Loss: 0.1477
# Epoch: 309, Loss: 0.1477
# Epoch: 310, Loss: 0.1476
# Epoch: 311, Loss: 0.1476
# Epoch: 312, Loss: 0.1476
# Epoch: 313, Loss: 0.1476
# Epoch: 314, Loss: 0.1476
# Epoch: 315, Loss: 0.1476
# Epoch: 316, Loss: 0.1476
# Epoch: 317, Loss: 0.1476
# Epoch: 318, Loss: 0.1476
# Epoch: 319, Loss: 0.1476
# Epoch: 320, Loss: 0.1476
# Epoch: 321, Loss: 0.1476
# Epoch: 322, Loss: 0.1475
# Epoch: 323, Loss: 0.1475
# Epoch: 324, Loss: 0.1475
# Epoch: 325, Loss: 0.1475
# Epoch: 326, Loss: 0.1475
# Epoch: 327, Loss: 0.1475
# Epoch: 328, Loss: 0.1475
# Epoch: 329, Loss: 0.1475
# Epoch: 330, Loss: 0.1475
# Epoch: 331, Loss: 0.1475
# Epoch: 332, Loss: 0.1475
# Epoch: 333, Loss: 0.1475
# Epoch: 334, Loss: 0.1475
# Epoch: 335, Loss: 0.1474
# Epoch: 336, Loss: 0.1474
# Epoch: 337, Loss: 0.1474
# Epoch: 338, Loss: 0.1474
# Epoch: 339, Loss: 0.1474
# Epoch: 340, Loss: 0.1474
# Epoch: 341, Loss: 0.1474
# Epoch: 342, Loss: 0.1474
# Epoch: 343, Loss: 0.1474
# Epoch: 344, Loss: 0.1474
# Epoch: 345, Loss: 0.1474
# Epoch: 346, Loss: 0.1474
# Epoch: 347, Loss: 0.1474
# Epoch: 348, Loss: 0.1474
# Epoch: 349, Loss: 0.1473
# Epoch: 350, Loss: 0.1473
# Epoch: 351, Loss: 0.1473
# Epoch: 352, Loss: 0.1473
# Epoch: 353, Loss: 0.1473
# Epoch: 354, Loss: 0.1473
# Epoch: 355, Loss: 0.1473
# Epoch: 356, Loss: 0.1473
# Epoch: 357, Loss: 0.1473
# Epoch: 358, Loss: 0.1473
# Epoch: 359, Loss: 0.1473
# Epoch: 360, Loss: 0.1473
# Epoch: 361, Loss: 0.1473
# Epoch: 362, Loss: 0.1473
# Epoch: 363, Loss: 0.1473
# Epoch: 364, Loss: 0.1473
# Epoch: 365, Loss: 0.1472
# Epoch: 366, Loss: 0.1472
# Epoch: 367, Loss: 0.1472
# Epoch: 368, Loss: 0.1472
# Epoch: 369, Loss: 0.1472
# Epoch: 370, Loss: 0.1472
# Epoch: 371, Loss: 0.1472
# Epoch: 372, Loss: 0.1472
# Epoch: 373, Loss: 0.1472
# Epoch: 374, Loss: 0.1472
# Epoch: 375, Loss: 0.1472
# Epoch: 376, Loss: 0.1472
# Epoch: 377, Loss: 0.1472
# Epoch: 378, Loss: 0.1472
# Epoch: 379, Loss: 0.1472
# Epoch: 380, Loss: 0.1472
# Epoch: 381, Loss: 0.1472
# Epoch: 382, Loss: 0.1472
# Epoch: 383, Loss: 0.1472
# Epoch: 384, Loss: 0.1471
# Epoch: 385, Loss: 0.1471
# Epoch: 386, Loss: 0.1471
# Epoch: 387, Loss: 0.1471
# Epoch: 388, Loss: 0.1471
# Epoch: 389, Loss: 0.1471
# Epoch: 390, Loss: 0.1471
# Epoch: 391, Loss: 0.1471
# Epoch: 392, Loss: 0.1471
# Epoch: 393, Loss: 0.1471
# Epoch: 394, Loss: 0.1471
# Epoch: 395, Loss: 0.1471
# Epoch: 396, Loss: 0.1471
# Epoch: 397, Loss: 0.1471
# Epoch: 398, Loss: 0.1471
# Epoch: 399, Loss: 0.1471
# Epoch: 400, Loss: 0.1471
# Epoch: 401, Loss: 0.1471
# Epoch: 402, Loss: 0.1471
# Epoch: 403, Loss: 0.1471
# Epoch: 404, Loss: 0.1471
# Epoch: 405, Loss: 0.1470
# Epoch: 406, Loss: 0.1470
# Epoch: 407, Loss: 0.1470
# Epoch: 408, Loss: 0.1470
# Epoch: 409, Loss: 0.1470
# Epoch: 410, Loss: 0.1470
# Epoch: 411, Loss: 0.1470
# Epoch: 412, Loss: 0.1470
# Epoch: 413, Loss: 0.1470
# Epoch: 414, Loss: 0.1470
# Epoch: 415, Loss: 0.1470
# Epoch: 416, Loss: 0.1470
# Epoch: 417, Loss: 0.1470
# Epoch: 418, Loss: 0.1470
# Epoch: 419, Loss: 0.1470
# Epoch: 420, Loss: 0.1470
# Epoch: 421, Loss: 0.1470
# Epoch: 422, Loss: 0.1470
# Epoch: 423, Loss: 0.1470
# Epoch: 424, Loss: 0.1470
# Epoch: 425, Loss: 0.1470
# Epoch: 426, Loss: 0.1470
# Epoch: 427, Loss: 0.1470
# Epoch: 428, Loss: 0.1470
# Epoch: 429, Loss: 0.1469
# Epoch: 430, Loss: 0.1469
# Epoch: 431, Loss: 0.1469
# Epoch: 432, Loss: 0.1469
# Epoch: 433, Loss: 0.1469
# Epoch: 434, Loss: 0.1469
# Epoch: 435, Loss: 0.1469
# Epoch: 436, Loss: 0.1469
# Epoch: 437, Loss: 0.1469
# Epoch: 438, Loss: 0.1469
# Epoch: 439, Loss: 0.1469
# Epoch: 440, Loss: 0.1469
# Epoch: 441, Loss: 0.1469
# Epoch: 442, Loss: 0.1469
# Epoch: 443, Loss: 0.1469
# Epoch: 444, Loss: 0.1469
# Epoch: 445, Loss: 0.1469
# Epoch: 446, Loss: 0.1469
# Epoch: 447, Loss: 0.1469
# Epoch: 448, Loss: 0.1469
# Epoch: 449, Loss: 0.1469
# Epoch: 450, Loss: 0.1469
# Epoch: 451, Loss: 0.1469
# Epoch: 452, Loss: 0.1469
# Epoch: 453, Loss: 0.1469
# Epoch: 454, Loss: 0.1469
# Epoch: 455, Loss: 0.1469
# Epoch: 456, Loss: 0.1469
# Epoch: 457, Loss: 0.1468
# Epoch: 458, Loss: 0.1468
# Epoch: 459, Loss: 0.1468
# Epoch: 460, Loss: 0.1468
# Epoch: 461, Loss: 0.1468
# Epoch: 462, Loss: 0.1468
# Epoch: 463, Loss: 0.1468
# Epoch: 464, Loss: 0.1468
# Epoch: 465, Loss: 0.1468
# Epoch: 466, Loss: 0.1468
# Epoch: 467, Loss: 0.1468
# Epoch: 468, Loss: 0.1468
# Epoch: 469, Loss: 0.1468
# Epoch: 470, Loss: 0.1468
# Epoch: 471, Loss: 0.1468
# Epoch: 472, Loss: 0.1468
# Epoch: 473, Loss: 0.1468
# Epoch: 474, Loss: 0.1468
# Epoch: 475, Loss: 0.1468
# Epoch: 476, Loss: 0.1468
# Epoch: 477, Loss: 0.1468
# Epoch: 478, Loss: 0.1468
# Epoch: 479, Loss: 0.1468
# Epoch: 480, Loss: 0.1468
# Epoch: 481, Loss: 0.1468
# Epoch: 482, Loss: 0.1468
# Epoch: 483, Loss: 0.1468
# Epoch: 484, Loss: 0.1468
# Epoch: 485, Loss: 0.1468
# Epoch: 486, Loss: 0.1468
# Epoch: 487, Loss: 0.1468
# Epoch: 488, Loss: 0.1468
# Epoch: 489, Loss: 0.1468
# Epoch: 490, Loss: 0.1467
# Epoch: 491, Loss: 0.1467
# Epoch: 492, Loss: 0.1467
# Epoch: 493, Loss: 0.1467
# Epoch: 494, Loss: 0.1467
# Epoch: 495, Loss: 0.1467
# Epoch: 496, Loss: 0.1467
# Epoch: 497, Loss: 0.1467
# Epoch: 498, Loss: 0.1467
# Epoch: 499, Loss: 0.1467
# Test Accuracy: 0.7416

# %%
data = from_networkx(subway_graph, y[tract_indices+subway_indices])
model = GCN(hidden_channels=16)
print(model)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()

for epoch in range(1, 500):
    loss = train(data)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')

out = model(data.x.to(torch.float), data.edge_index)
test_acc = test(data)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# GCN(
#   (conv1): GCNConv(2637, 16)
#   (conv2): GCNConv(16, 4)
#   (conv3): GCNConv(4, 2)
#   (classifier): Linear(in_features=2, out_features=4, bias=True)
# )
# Epoch: 001, Loss: 0.6938
# Epoch: 002, Loss: 0.6344
# Epoch: 003, Loss: 0.5849
# Epoch: 004, Loss: 0.5444
# Epoch: 005, Loss: 0.5117
# Epoch: 006, Loss: 0.4849
# Epoch: 007, Loss: 0.4617
# Epoch: 008, Loss: 0.4397
# Epoch: 009, Loss: 0.4174
# Epoch: 010, Loss: 0.3938
# Epoch: 011, Loss: 0.3694
# Epoch: 012, Loss: 0.3454
# Epoch: 013, Loss: 0.3236
# Epoch: 014, Loss: 0.3049
# Epoch: 015, Loss: 0.2898
# Epoch: 016, Loss: 0.2776
# Epoch: 017, Loss: 0.2676
# Epoch: 018, Loss: 0.2590
# Epoch: 019, Loss: 0.2511
# Epoch: 020, Loss: 0.2437
# Epoch: 021, Loss: 0.2367
# Epoch: 022, Loss: 0.2302
# Epoch: 023, Loss: 0.2243
# Epoch: 024, Loss: 0.2192
# Epoch: 025, Loss: 0.2150
# Epoch: 026, Loss: 0.2116
# Epoch: 027, Loss: 0.2087
# Epoch: 028, Loss: 0.2062
# Epoch: 029, Loss: 0.2039
# Epoch: 030, Loss: 0.2017
# Epoch: 031, Loss: 0.1995
# Epoch: 032, Loss: 0.1975
# Epoch: 033, Loss: 0.1956
# Epoch: 034, Loss: 0.1939
# Epoch: 035, Loss: 0.1924
# Epoch: 036, Loss: 0.1911
# Epoch: 037, Loss: 0.1899
# Epoch: 038, Loss: 0.1887
# Epoch: 039, Loss: 0.1875
# Epoch: 040, Loss: 0.1864
# Epoch: 041, Loss: 0.1854
# Epoch: 042, Loss: 0.1843
# Epoch: 043, Loss: 0.1832
# Epoch: 044, Loss: 0.1821
# Epoch: 045, Loss: 0.1810
# Epoch: 046, Loss: 0.1800
# Epoch: 047, Loss: 0.1791
# Epoch: 048, Loss: 0.1781
# Epoch: 049, Loss: 0.1771
# Epoch: 050, Loss: 0.1762
# Epoch: 051, Loss: 0.1752
# Epoch: 052, Loss: 0.1743
# Epoch: 053, Loss: 0.1734
# Epoch: 054, Loss: 0.1726
# Epoch: 055, Loss: 0.1718
# Epoch: 056, Loss: 0.1710
# Epoch: 057, Loss: 0.1704
# Epoch: 058, Loss: 0.1697
# Epoch: 059, Loss: 0.1690
# Epoch: 060, Loss: 0.1684
# Epoch: 061, Loss: 0.1679
# Epoch: 062, Loss: 0.1674
# Epoch: 063, Loss: 0.1669
# Epoch: 064, Loss: 0.1664
# Epoch: 065, Loss: 0.1660
# Epoch: 066, Loss: 0.1655
# Epoch: 067, Loss: 0.1651
# Epoch: 068, Loss: 0.1647
# Epoch: 069, Loss: 0.1643
# Epoch: 070, Loss: 0.1639
# Epoch: 071, Loss: 0.1636
# Epoch: 072, Loss: 0.1632
# Epoch: 073, Loss: 0.1629
# Epoch: 074, Loss: 0.1625
# Epoch: 075, Loss: 0.1622
# Epoch: 076, Loss: 0.1619
# Epoch: 077, Loss: 0.1616
# Epoch: 078, Loss: 0.1613
# Epoch: 079, Loss: 0.1610
# Epoch: 080, Loss: 0.1608
# Epoch: 081, Loss: 0.1605
# Epoch: 082, Loss: 0.1603
# Epoch: 083, Loss: 0.1600
# Epoch: 084, Loss: 0.1598
# Epoch: 085, Loss: 0.1595
# Epoch: 086, Loss: 0.1593
# Epoch: 087, Loss: 0.1591
# Epoch: 088, Loss: 0.1589
# Epoch: 089, Loss: 0.1587
# Epoch: 090, Loss: 0.1584
# Epoch: 091, Loss: 0.1582
# Epoch: 092, Loss: 0.1580
# Epoch: 093, Loss: 0.1578
# Epoch: 094, Loss: 0.1576
# Epoch: 095, Loss: 0.1574
# Epoch: 096, Loss: 0.1573
# Epoch: 097, Loss: 0.1571
# Epoch: 098, Loss: 0.1569
# Epoch: 099, Loss: 0.1567
# Epoch: 100, Loss: 0.1566
# Epoch: 101, Loss: 0.1564
# Epoch: 102, Loss: 0.1563
# Epoch: 103, Loss: 0.1561
# Epoch: 104, Loss: 0.1559
# Epoch: 105, Loss: 0.1558
# Epoch: 106, Loss: 0.1557
# Epoch: 107, Loss: 0.1555
# Epoch: 108, Loss: 0.1554
# Epoch: 109, Loss: 0.1553
# Epoch: 110, Loss: 0.1551
# Epoch: 111, Loss: 0.1550
# Epoch: 112, Loss: 0.1549
# Epoch: 113, Loss: 0.1547
# Epoch: 114, Loss: 0.1546
# Epoch: 115, Loss: 0.1545
# Epoch: 116, Loss: 0.1544
# Epoch: 117, Loss: 0.1543
# Epoch: 118, Loss: 0.1542
# Epoch: 119, Loss: 0.1540
# Epoch: 120, Loss: 0.1539
# Epoch: 121, Loss: 0.1538
# Epoch: 122, Loss: 0.1537
# Epoch: 123, Loss: 0.1536
# Epoch: 124, Loss: 0.1535
# Epoch: 125, Loss: 0.1534
# Epoch: 126, Loss: 0.1533
# Epoch: 127, Loss: 0.1532
# Epoch: 128, Loss: 0.1531
# Epoch: 129, Loss: 0.1530
# Epoch: 130, Loss: 0.1529
# Epoch: 131, Loss: 0.1529
# Epoch: 132, Loss: 0.1528
# Epoch: 133, Loss: 0.1527
# Epoch: 134, Loss: 0.1526
# Epoch: 135, Loss: 0.1525
# Epoch: 136, Loss: 0.1524
# Epoch: 137, Loss: 0.1524
# Epoch: 138, Loss: 0.1523
# Epoch: 139, Loss: 0.1522
# Epoch: 140, Loss: 0.1521
# Epoch: 141, Loss: 0.1520
# Epoch: 142, Loss: 0.1520
# Epoch: 143, Loss: 0.1519
# Epoch: 144, Loss: 0.1518
# Epoch: 145, Loss: 0.1517
# Epoch: 146, Loss: 0.1517
# Epoch: 147, Loss: 0.1516
# Epoch: 148, Loss: 0.1515
# Epoch: 149, Loss: 0.1515
# Epoch: 150, Loss: 0.1514
# Epoch: 151, Loss: 0.1513
# Epoch: 152, Loss: 0.1513
# Epoch: 153, Loss: 0.1512
# Epoch: 154, Loss: 0.1511
# Epoch: 155, Loss: 0.1511
# Epoch: 156, Loss: 0.1510
# Epoch: 157, Loss: 0.1510
# Epoch: 158, Loss: 0.1509
# Epoch: 159, Loss: 0.1508
# Epoch: 160, Loss: 0.1508
# Epoch: 161, Loss: 0.1507
# Epoch: 162, Loss: 0.1507
# Epoch: 163, Loss: 0.1506
# Epoch: 164, Loss: 0.1506
# Epoch: 165, Loss: 0.1505
# Epoch: 166, Loss: 0.1505
# Epoch: 167, Loss: 0.1504
# Epoch: 168, Loss: 0.1504
# Epoch: 169, Loss: 0.1503
# Epoch: 170, Loss: 0.1503
# Epoch: 171, Loss: 0.1502
# Epoch: 172, Loss: 0.1502
# Epoch: 173, Loss: 0.1501
# Epoch: 174, Loss: 0.1501
# Epoch: 175, Loss: 0.1500
# Epoch: 176, Loss: 0.1500
# Epoch: 177, Loss: 0.1499
# Epoch: 178, Loss: 0.1499
# Epoch: 179, Loss: 0.1498
# Epoch: 180, Loss: 0.1498
# Epoch: 181, Loss: 0.1498
# Epoch: 182, Loss: 0.1497
# Epoch: 183, Loss: 0.1497
# Epoch: 184, Loss: 0.1496
# Epoch: 185, Loss: 0.1496
# Epoch: 186, Loss: 0.1495
# Epoch: 187, Loss: 0.1495
# Epoch: 188, Loss: 0.1494
# Epoch: 189, Loss: 0.1494
# Epoch: 190, Loss: 0.1494
# Epoch: 191, Loss: 0.1493
# Epoch: 192, Loss: 0.1493
# Epoch: 193, Loss: 0.1493
# Epoch: 194, Loss: 0.1492
# Epoch: 195, Loss: 0.1492
# Epoch: 196, Loss: 0.1491
# Epoch: 197, Loss: 0.1491
# Epoch: 198, Loss: 0.1491
# Epoch: 199, Loss: 0.1490
# Epoch: 200, Loss: 0.1490
# Epoch: 201, Loss: 0.1490
# Epoch: 202, Loss: 0.1489
# Epoch: 203, Loss: 0.1489
# Epoch: 204, Loss: 0.1489
# Epoch: 205, Loss: 0.1488
# Epoch: 206, Loss: 0.1488
# Epoch: 207, Loss: 0.1488
# Epoch: 208, Loss: 0.1487
# Epoch: 209, Loss: 0.1487
# Epoch: 210, Loss: 0.1487
# Epoch: 211, Loss: 0.1486
# Epoch: 212, Loss: 0.1486
# Epoch: 213, Loss: 0.1486
# Epoch: 214, Loss: 0.1485
# Epoch: 215, Loss: 0.1485
# Epoch: 216, Loss: 0.1485
# Epoch: 217, Loss: 0.1485
# Epoch: 218, Loss: 0.1484
# Epoch: 219, Loss: 0.1484
# Epoch: 220, Loss: 0.1484
# Epoch: 221, Loss: 0.1483
# Epoch: 222, Loss: 0.1483
# Epoch: 223, Loss: 0.1483
# Epoch: 224, Loss: 0.1483
# Epoch: 225, Loss: 0.1482
# Epoch: 226, Loss: 0.1482
# Epoch: 227, Loss: 0.1482
# Epoch: 228, Loss: 0.1481
# Epoch: 229, Loss: 0.1481
# Epoch: 230, Loss: 0.1481
# Epoch: 231, Loss: 0.1481
# Epoch: 232, Loss: 0.1480
# Epoch: 233, Loss: 0.1480
# Epoch: 234, Loss: 0.1480
# Epoch: 235, Loss: 0.1480
# Epoch: 236, Loss: 0.1479
# Epoch: 237, Loss: 0.1479
# Epoch: 238, Loss: 0.1479
# Epoch: 239, Loss: 0.1479
# Epoch: 240, Loss: 0.1478
# Epoch: 241, Loss: 0.1478
# Epoch: 242, Loss: 0.1478
# Epoch: 243, Loss: 0.1478
# Epoch: 244, Loss: 0.1478
# Epoch: 245, Loss: 0.1477
# Epoch: 246, Loss: 0.1477
# Epoch: 247, Loss: 0.1477
# Epoch: 248, Loss: 0.1477
# Epoch: 249, Loss: 0.1477
# Epoch: 250, Loss: 0.1476
# Epoch: 251, Loss: 0.1476
# Epoch: 252, Loss: 0.1476
# Epoch: 253, Loss: 0.1476
# Epoch: 254, Loss: 0.1475
# Epoch: 255, Loss: 0.1475
# Epoch: 256, Loss: 0.1475
# Epoch: 257, Loss: 0.1475
# Epoch: 258, Loss: 0.1474
# Epoch: 259, Loss: 0.1474
# Epoch: 260, Loss: 0.1474
# Epoch: 261, Loss: 0.1474
# Epoch: 262, Loss: 0.1474
# Epoch: 263, Loss: 0.1474
# Epoch: 264, Loss: 0.1473
# Epoch: 265, Loss: 0.1473
# Epoch: 266, Loss: 0.1473
# Epoch: 267, Loss: 0.1473
# Epoch: 268, Loss: 0.1473
# Epoch: 269, Loss: 0.1472
# Epoch: 270, Loss: 0.1472
# Epoch: 271, Loss: 0.1472
# Epoch: 272, Loss: 0.1472
# Epoch: 273, Loss: 0.1472
# Epoch: 274, Loss: 0.1471
# Epoch: 275, Loss: 0.1471
# Epoch: 276, Loss: 0.1471
# Epoch: 277, Loss: 0.1471
# Epoch: 278, Loss: 0.1471
# Epoch: 279, Loss: 0.1471
# Epoch: 280, Loss: 0.1470
# Epoch: 281, Loss: 0.1470
# Epoch: 282, Loss: 0.1470
# Epoch: 283, Loss: 0.1470
# Epoch: 284, Loss: 0.1470
# Epoch: 285, Loss: 0.1470
# Epoch: 286, Loss: 0.1469
# Epoch: 287, Loss: 0.1469
# Epoch: 288, Loss: 0.1469
# Epoch: 289, Loss: 0.1469
# Epoch: 290, Loss: 0.1469
# Epoch: 291, Loss: 0.1469
# Epoch: 292, Loss: 0.1468
# Epoch: 293, Loss: 0.1468
# Epoch: 294, Loss: 0.1468
# Epoch: 295, Loss: 0.1468
# Epoch: 296, Loss: 0.1468
# Epoch: 297, Loss: 0.1468
# Epoch: 298, Loss: 0.1468
# Epoch: 299, Loss: 0.1468
# Epoch: 300, Loss: 0.1468
# Epoch: 301, Loss: 0.1468
# Epoch: 302, Loss: 0.1467
# Epoch: 303, Loss: 0.1467
# Epoch: 304, Loss: 0.1467
# Epoch: 305, Loss: 0.1466
# Epoch: 306, Loss: 0.1466
# Epoch: 307, Loss: 0.1466
# Epoch: 308, Loss: 0.1466
# Epoch: 309, Loss: 0.1466
# Epoch: 310, Loss: 0.1466
# Epoch: 311, Loss: 0.1466
# Epoch: 312, Loss: 0.1466
# Epoch: 313, Loss: 0.1465
# Epoch: 314, Loss: 0.1465
# Epoch: 315, Loss: 0.1465
# Epoch: 316, Loss: 0.1465
# Epoch: 317, Loss: 0.1465
# Epoch: 318, Loss: 0.1465
# Epoch: 319, Loss: 0.1465
# Epoch: 320, Loss: 0.1465
# Epoch: 321, Loss: 0.1464
# Epoch: 322, Loss: 0.1464
# Epoch: 323, Loss: 0.1464
# Epoch: 324, Loss: 0.1464
# Epoch: 325, Loss: 0.1464
# Epoch: 326, Loss: 0.1464
# Epoch: 327, Loss: 0.1464
# Epoch: 328, Loss: 0.1464
# Epoch: 329, Loss: 0.1463
# Epoch: 330, Loss: 0.1463
# Epoch: 331, Loss: 0.1463
# Epoch: 332, Loss: 0.1463
# Epoch: 333, Loss: 0.1463
# Epoch: 334, Loss: 0.1463
# Epoch: 335, Loss: 0.1463
# Epoch: 336, Loss: 0.1463
# Epoch: 337, Loss: 0.1462
# Epoch: 338, Loss: 0.1462
# Epoch: 339, Loss: 0.1462
# Epoch: 340, Loss: 0.1462
# Epoch: 341, Loss: 0.1462
# Epoch: 342, Loss: 0.1462
# Epoch: 343, Loss: 0.1462
# Epoch: 344, Loss: 0.1462
# Epoch: 345, Loss: 0.1462
# Epoch: 346, Loss: 0.1462
# Epoch: 347, Loss: 0.1461
# Epoch: 348, Loss: 0.1461
# Epoch: 349, Loss: 0.1461
# Epoch: 350, Loss: 0.1461
# Epoch: 351, Loss: 0.1461
# Epoch: 352, Loss: 0.1461
# Epoch: 353, Loss: 0.1461
# Epoch: 354, Loss: 0.1461
# Epoch: 355, Loss: 0.1461
# Epoch: 356, Loss: 0.1461
# Epoch: 357, Loss: 0.1460
# Epoch: 358, Loss: 0.1461
# Epoch: 359, Loss: 0.1460
# Epoch: 360, Loss: 0.1460
# Epoch: 361, Loss: 0.1460
# Epoch: 362, Loss: 0.1460
# Epoch: 363, Loss: 0.1460
# Epoch: 364, Loss: 0.1460
# Epoch: 365, Loss: 0.1459
# Epoch: 366, Loss: 0.1459
# Epoch: 367, Loss: 0.1459
# Epoch: 368, Loss: 0.1459
# Epoch: 369, Loss: 0.1459
# Epoch: 370, Loss: 0.1459
# Epoch: 371, Loss: 0.1459
# Epoch: 372, Loss: 0.1459
# Epoch: 373, Loss: 0.1459
# Epoch: 374, Loss: 0.1459
# Epoch: 375, Loss: 0.1459
# Epoch: 376, Loss: 0.1459
# Epoch: 377, Loss: 0.1459
# Epoch: 378, Loss: 0.1458
# Epoch: 379, Loss: 0.1458
# Epoch: 380, Loss: 0.1458
# Epoch: 381, Loss: 0.1458
# Epoch: 382, Loss: 0.1458
# Epoch: 383, Loss: 0.1458
# Epoch: 384, Loss: 0.1458
# Epoch: 385, Loss: 0.1458
# Epoch: 386, Loss: 0.1458
# Epoch: 387, Loss: 0.1458
# Epoch: 388, Loss: 0.1458
# Epoch: 389, Loss: 0.1457
# Epoch: 390, Loss: 0.1458
# Epoch: 391, Loss: 0.1457
# Epoch: 392, Loss: 0.1457
# Epoch: 393, Loss: 0.1457
# Epoch: 394, Loss: 0.1457
# Epoch: 395, Loss: 0.1457
# Epoch: 396, Loss: 0.1457
# Epoch: 397, Loss: 0.1457
# Epoch: 398, Loss: 0.1457
# Epoch: 399, Loss: 0.1456
# Epoch: 400, Loss: 0.1456
# Epoch: 401, Loss: 0.1456
# Epoch: 402, Loss: 0.1456
# Epoch: 403, Loss: 0.1456
# Epoch: 404, Loss: 0.1456
# Epoch: 405, Loss: 0.1456
# Epoch: 406, Loss: 0.1456
# Epoch: 407, Loss: 0.1456
# Epoch: 408, Loss: 0.1456
# Epoch: 409, Loss: 0.1456
# Epoch: 410, Loss: 0.1456
# Epoch: 411, Loss: 0.1456
# Epoch: 412, Loss: 0.1456
# Epoch: 413, Loss: 0.1456
# Epoch: 414, Loss: 0.1455
# Epoch: 415, Loss: 0.1455
# Epoch: 416, Loss: 0.1455
# Epoch: 417, Loss: 0.1455
# Epoch: 418, Loss: 0.1455
# Epoch: 419, Loss: 0.1455
# Epoch: 420, Loss: 0.1455
# Epoch: 421, Loss: 0.1455
# Epoch: 422, Loss: 0.1455
# Epoch: 423, Loss: 0.1455
# Epoch: 424, Loss: 0.1455
# Epoch: 425, Loss: 0.1455
# Epoch: 426, Loss: 0.1455
# Epoch: 427, Loss: 0.1455
# Epoch: 428, Loss: 0.1455
# Epoch: 429, Loss: 0.1454
# Epoch: 430, Loss: 0.1454
# Epoch: 431, Loss: 0.1454
# Epoch: 432, Loss: 0.1454
# Epoch: 433, Loss: 0.1454
# Epoch: 434, Loss: 0.1454
# Epoch: 435, Loss: 0.1454
# Epoch: 436, Loss: 0.1454
# Epoch: 437, Loss: 0.1454
# Epoch: 438, Loss: 0.1454
# Epoch: 439, Loss: 0.1454
# Epoch: 440, Loss: 0.1454
# Epoch: 441, Loss: 0.1454
# Epoch: 442, Loss: 0.1454
# Epoch: 443, Loss: 0.1454
# Epoch: 444, Loss: 0.1453
# Epoch: 445, Loss: 0.1454
# Epoch: 446, Loss: 0.1453
# Epoch: 447, Loss: 0.1453
# Epoch: 448, Loss: 0.1453
# Epoch: 449, Loss: 0.1453
# Epoch: 450, Loss: 0.1453
# Epoch: 451, Loss: 0.1453
# Epoch: 452, Loss: 0.1453
# Epoch: 453, Loss: 0.1453
# Epoch: 454, Loss: 0.1453
# Epoch: 455, Loss: 0.1453
# Epoch: 456, Loss: 0.1453
# Epoch: 457, Loss: 0.1453
# Epoch: 458, Loss: 0.1453
# Epoch: 459, Loss: 0.1453
# Epoch: 460, Loss: 0.1453
# Epoch: 461, Loss: 0.1452
# Epoch: 462, Loss: 0.1452
# Epoch: 463, Loss: 0.1452
# Epoch: 464, Loss: 0.1452
# Epoch: 465, Loss: 0.1452
# Epoch: 466, Loss: 0.1452
# Epoch: 467, Loss: 0.1452
# Epoch: 468, Loss: 0.1452
# Epoch: 469, Loss: 0.1452
# Epoch: 470, Loss: 0.1452
# Epoch: 471, Loss: 0.1452
# Epoch: 472, Loss: 0.1452
# Epoch: 473, Loss: 0.1452
# Epoch: 474, Loss: 0.1452
# Epoch: 475, Loss: 0.1452
# Epoch: 476, Loss: 0.1452
# Epoch: 477, Loss: 0.1452
# Epoch: 478, Loss: 0.1451
# Epoch: 479, Loss: 0.1451
# Epoch: 480, Loss: 0.1451
# Epoch: 481, Loss: 0.1451
# Epoch: 482, Loss: 0.1451
# Epoch: 483, Loss: 0.1451
# Epoch: 484, Loss: 0.1451
# Epoch: 485, Loss: 0.1451
# Epoch: 486, Loss: 0.1451
# Epoch: 487, Loss: 0.1451
# Epoch: 488, Loss: 0.1451
# Epoch: 489, Loss: 0.1451
# Epoch: 490, Loss: 0.1451
# Epoch: 491, Loss: 0.1451
# Epoch: 492, Loss: 0.1451
# Epoch: 493, Loss: 0.1451
# Epoch: 494, Loss: 0.1451
# Epoch: 495, Loss: 0.1450
# Epoch: 496, Loss: 0.1450
# Epoch: 497, Loss: 0.1450
# Epoch: 498, Loss: 0.1450
# Epoch: 499, Loss: 0.1450
# Test Accuracy: 0.7727

# %%
data = from_networkx(schools_graph, y[tract_indices+school_indices])
model = GCN(hidden_channels=16)
print(model)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
criterion = torch.nn.CrossEntropyLoss()

for epoch in range(1, 500):
    loss = train(data)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')

out = model(data.x.to(torch.float), data.edge_index)
test_acc = test(data)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# GCN(
#   (conv1): GCNConv(3981, 16)
#   (conv2): GCNConv(16, 4)
#   (conv3): GCNConv(4, 2)
#   (classifier): Linear(in_features=2, out_features=4, bias=True)
# )
# Epoch: 001, Loss: 0.6937
# Epoch: 002, Loss: 0.6337
# Epoch: 003, Loss: 0.5817
# Epoch: 004, Loss: 0.5391
# Epoch: 005, Loss: 0.5054
# Epoch: 006, Loss: 0.4768
# Epoch: 007, Loss: 0.4484
# Epoch: 008, Loss: 0.4173
# Epoch: 009, Loss: 0.3832
# Epoch: 010, Loss: 0.3487
# Epoch: 011, Loss: 0.3172
# Epoch: 012, Loss: 0.2914
# Epoch: 013, Loss: 0.2719
# Epoch: 014, Loss: 0.2576
# Epoch: 015, Loss: 0.2465
# Epoch: 016, Loss: 0.2367
# Epoch: 017, Loss: 0.2272
# Epoch: 018, Loss: 0.2177
# Epoch: 019, Loss: 0.2088
# Epoch: 020, Loss: 0.2011
# Epoch: 021, Loss: 0.1952
# Epoch: 022, Loss: 0.1912
# Epoch: 023, Loss: 0.1884
# Epoch: 024, Loss: 0.1863
# Epoch: 025, Loss: 0.1842
# Epoch: 026, Loss: 0.1819
# Epoch: 027, Loss: 0.1795
# Epoch: 028, Loss: 0.1773
# Epoch: 029, Loss: 0.1757
# Epoch: 030, Loss: 0.1747
# Epoch: 031, Loss: 0.1742
# Epoch: 032, Loss: 0.1738
# Epoch: 033, Loss: 0.1732
# Epoch: 034, Loss: 0.1724
# Epoch: 035, Loss: 0.1715
# Epoch: 036, Loss: 0.1707
# Epoch: 037, Loss: 0.1701
# Epoch: 038, Loss: 0.1697
# Epoch: 039, Loss: 0.1692
# Epoch: 040, Loss: 0.1686
# Epoch: 041, Loss: 0.1679
# Epoch: 042, Loss: 0.1672
# Epoch: 043, Loss: 0.1667
# Epoch: 044, Loss: 0.1661
# Epoch: 045, Loss: 0.1655
# Epoch: 046, Loss: 0.1649
# Epoch: 047, Loss: 0.1644
# Epoch: 048, Loss: 0.1639
# Epoch: 049, Loss: 0.1633
# Epoch: 050, Loss: 0.1626
# Epoch: 051, Loss: 0.1619
# Epoch: 052, Loss: 0.1613
# Epoch: 053, Loss: 0.1607
# Epoch: 054, Loss: 0.1601
# Epoch: 055, Loss: 0.1595
# Epoch: 056, Loss: 0.1590
# Epoch: 057, Loss: 0.1585
# Epoch: 058, Loss: 0.1580
# Epoch: 059, Loss: 0.1575
# Epoch: 060, Loss: 0.1570
# Epoch: 061, Loss: 0.1565
# Epoch: 062, Loss: 0.1561
# Epoch: 063, Loss: 0.1556
# Epoch: 064, Loss: 0.1552
# Epoch: 065, Loss: 0.1548
# Epoch: 066, Loss: 0.1544
# Epoch: 067, Loss: 0.1540
# Epoch: 068, Loss: 0.1537
# Epoch: 069, Loss: 0.1534
# Epoch: 070, Loss: 0.1531
# Epoch: 071, Loss: 0.1528
# Epoch: 072, Loss: 0.1525
# Epoch: 073, Loss: 0.1522
# Epoch: 074, Loss: 0.1519
# Epoch: 075, Loss: 0.1517
# Epoch: 076, Loss: 0.1514
# Epoch: 077, Loss: 0.1512
# Epoch: 078, Loss: 0.1510
# Epoch: 079, Loss: 0.1507
# Epoch: 080, Loss: 0.1505
# Epoch: 081, Loss: 0.1503
# Epoch: 082, Loss: 0.1500
# Epoch: 083, Loss: 0.1498
# Epoch: 084, Loss: 0.1496
# Epoch: 085, Loss: 0.1494
# Epoch: 086, Loss: 0.1491
# Epoch: 087, Loss: 0.1489
# Epoch: 088, Loss: 0.1487
# Epoch: 089, Loss: 0.1485
# Epoch: 090, Loss: 0.1483
# Epoch: 091, Loss: 0.1481
# Epoch: 092, Loss: 0.1480
# Epoch: 093, Loss: 0.1478
# Epoch: 094, Loss: 0.1476
# Epoch: 095, Loss: 0.1474
# Epoch: 096, Loss: 0.1473
# Epoch: 097, Loss: 0.1471
# Epoch: 098, Loss: 0.1470
# Epoch: 099, Loss: 0.1468
# Epoch: 100, Loss: 0.1466
# Epoch: 101, Loss: 0.1465
# Epoch: 102, Loss: 0.1463
# Epoch: 103, Loss: 0.1462
# Epoch: 104, Loss: 0.1461
# Epoch: 105, Loss: 0.1459
# Epoch: 106, Loss: 0.1458
# Epoch: 107, Loss: 0.1456
# Epoch: 108, Loss: 0.1455
# Epoch: 109, Loss: 0.1454
# Epoch: 110, Loss: 0.1452
# Epoch: 111, Loss: 0.1451
# Epoch: 112, Loss: 0.1450
# Epoch: 113, Loss: 0.1449
# Epoch: 114, Loss: 0.1448
# Epoch: 115, Loss: 0.1446
# Epoch: 116, Loss: 0.1445
# Epoch: 117, Loss: 0.1444
# Epoch: 118, Loss: 0.1443
# Epoch: 119, Loss: 0.1442
# Epoch: 120, Loss: 0.1441
# Epoch: 121, Loss: 0.1440
# Epoch: 122, Loss: 0.1439
# Epoch: 123, Loss: 0.1437
# Epoch: 124, Loss: 0.1436
# Epoch: 125, Loss: 0.1436
# Epoch: 126, Loss: 0.1435
# Epoch: 127, Loss: 0.1434
# Epoch: 128, Loss: 0.1433
# Epoch: 129, Loss: 0.1432
# Epoch: 130, Loss: 0.1431
# Epoch: 131, Loss: 0.1430
# Epoch: 132, Loss: 0.1429
# Epoch: 133, Loss: 0.1428
# Epoch: 134, Loss: 0.1427
# Epoch: 135, Loss: 0.1426
# Epoch: 136, Loss: 0.1426
# Epoch: 137, Loss: 0.1425
# Epoch: 138, Loss: 0.1424
# Epoch: 139, Loss: 0.1423
# Epoch: 140, Loss: 0.1422
# Epoch: 141, Loss: 0.1422
# Epoch: 142, Loss: 0.1421
# Epoch: 143, Loss: 0.1420
# Epoch: 144, Loss: 0.1419
# Epoch: 145, Loss: 0.1418
# Epoch: 146, Loss: 0.1418
# Epoch: 147, Loss: 0.1417
# Epoch: 148, Loss: 0.1416
# Epoch: 149, Loss: 0.1416
# Epoch: 150, Loss: 0.1415
# Epoch: 151, Loss: 0.1414
# Epoch: 152, Loss: 0.1414
# Epoch: 153, Loss: 0.1413
# Epoch: 154, Loss: 0.1412
# Epoch: 155, Loss: 0.1412
# Epoch: 156, Loss: 0.1411
# Epoch: 157, Loss: 0.1410
# Epoch: 158, Loss: 0.1410
# Epoch: 159, Loss: 0.1409
# Epoch: 160, Loss: 0.1409
# Epoch: 161, Loss: 0.1408
# Epoch: 162, Loss: 0.1407
# Epoch: 163, Loss: 0.1407
# Epoch: 164, Loss: 0.1406
# Epoch: 165, Loss: 0.1406
# Epoch: 166, Loss: 0.1405
# Epoch: 167, Loss: 0.1404
# Epoch: 168, Loss: 0.1404
# Epoch: 169, Loss: 0.1403
# Epoch: 170, Loss: 0.1403
# Epoch: 171, Loss: 0.1402
# Epoch: 172, Loss: 0.1402
# Epoch: 173, Loss: 0.1401
# Epoch: 174, Loss: 0.1401
# Epoch: 175, Loss: 0.1400
# Epoch: 176, Loss: 0.1400
# Epoch: 177, Loss: 0.1399
# Epoch: 178, Loss: 0.1399
# Epoch: 179, Loss: 0.1399
# Epoch: 180, Loss: 0.1398
# Epoch: 181, Loss: 0.1397
# Epoch: 182, Loss: 0.1397
# Epoch: 183, Loss: 0.1396
# Epoch: 184, Loss: 0.1396
# Epoch: 185, Loss: 0.1396
# Epoch: 186, Loss: 0.1395
# Epoch: 187, Loss: 0.1395
# Epoch: 188, Loss: 0.1394
# Epoch: 189, Loss: 0.1394
# Epoch: 190, Loss: 0.1393
# Epoch: 191, Loss: 0.1393
# Epoch: 192, Loss: 0.1393
# Epoch: 193, Loss: 0.1392
# Epoch: 194, Loss: 0.1392
# Epoch: 195, Loss: 0.1391
# Epoch: 196, Loss: 0.1391
# Epoch: 197, Loss: 0.1390
# Epoch: 198, Loss: 0.1390
# Epoch: 199, Loss: 0.1390
# Epoch: 200, Loss: 0.1389
# Epoch: 201, Loss: 0.1389
# Epoch: 202, Loss: 0.1389
# Epoch: 203, Loss: 0.1388
# Epoch: 204, Loss: 0.1388
# Epoch: 205, Loss: 0.1387
# Epoch: 206, Loss: 0.1387
# Epoch: 207, Loss: 0.1387
# Epoch: 208, Loss: 0.1386
# Epoch: 209, Loss: 0.1386
# Epoch: 210, Loss: 0.1386
# Epoch: 211, Loss: 0.1385
# Epoch: 212, Loss: 0.1385
# Epoch: 213, Loss: 0.1385
# Epoch: 214, Loss: 0.1384
# Epoch: 215, Loss: 0.1384
# Epoch: 216, Loss: 0.1384
# Epoch: 217, Loss: 0.1383
# Epoch: 218, Loss: 0.1383
# Epoch: 219, Loss: 0.1383
# Epoch: 220, Loss: 0.1383
# Epoch: 221, Loss: 0.1382
# Epoch: 222, Loss: 0.1382
# Epoch: 223, Loss: 0.1382
# Epoch: 224, Loss: 0.1381
# Epoch: 225, Loss: 0.1381
# Epoch: 226, Loss: 0.1381
# Epoch: 227, Loss: 0.1380
# Epoch: 228, Loss: 0.1380
# Epoch: 229, Loss: 0.1380
# Epoch: 230, Loss: 0.1380
# Epoch: 231, Loss: 0.1379
# Epoch: 232, Loss: 0.1379
# Epoch: 233, Loss: 0.1379
# Epoch: 234, Loss: 0.1379
# Epoch: 235, Loss: 0.1378
# Epoch: 236, Loss: 0.1378
# Epoch: 237, Loss: 0.1378
# Epoch: 238, Loss: 0.1378
# Epoch: 239, Loss: 0.1377
# Epoch: 240, Loss: 0.1377
# Epoch: 241, Loss: 0.1376
# Epoch: 242, Loss: 0.1376
# Epoch: 243, Loss: 0.1376
# Epoch: 244, Loss: 0.1376
# Epoch: 245, Loss: 0.1376
# Epoch: 246, Loss: 0.1376
# Epoch: 247, Loss: 0.1375
# Epoch: 248, Loss: 0.1375
# Epoch: 249, Loss: 0.1375
# Epoch: 250, Loss: 0.1374
# Epoch: 251, Loss: 0.1374
# Epoch: 252, Loss: 0.1374
# Epoch: 253, Loss: 0.1374
# Epoch: 254, Loss: 0.1374
# Epoch: 255, Loss: 0.1373
# Epoch: 256, Loss: 0.1373
# Epoch: 257, Loss: 0.1373
# Epoch: 258, Loss: 0.1373
# Epoch: 259, Loss: 0.1372
# Epoch: 260, Loss: 0.1372
# Epoch: 261, Loss: 0.1372
# Epoch: 262, Loss: 0.1372
# Epoch: 263, Loss: 0.1372
# Epoch: 264, Loss: 0.1371
# Epoch: 265, Loss: 0.1371
# Epoch: 266, Loss: 0.1371
# Epoch: 267, Loss: 0.1371
# Epoch: 268, Loss: 0.1370
# Epoch: 269, Loss: 0.1370
# Epoch: 270, Loss: 0.1370
# Epoch: 271, Loss: 0.1370
# Epoch: 272, Loss: 0.1370
# Epoch: 273, Loss: 0.1369
# Epoch: 274, Loss: 0.1369
# Epoch: 275, Loss: 0.1369
# Epoch: 276, Loss: 0.1369
# Epoch: 277, Loss: 0.1369
# Epoch: 278, Loss: 0.1369
# Epoch: 279, Loss: 0.1368
# Epoch: 280, Loss: 0.1368
# Epoch: 281, Loss: 0.1368
# Epoch: 282, Loss: 0.1368
# Epoch: 283, Loss: 0.1368
# Epoch: 284, Loss: 0.1368
# Epoch: 285, Loss: 0.1368
# Epoch: 286, Loss: 0.1368
# Epoch: 287, Loss: 0.1367
# Epoch: 288, Loss: 0.1367
# Epoch: 289, Loss: 0.1367
# Epoch: 290, Loss: 0.1366
# Epoch: 291, Loss: 0.1366
# Epoch: 292, Loss: 0.1366
# Epoch: 293, Loss: 0.1366
# Epoch: 294, Loss: 0.1366
# Epoch: 295, Loss: 0.1366
# Epoch: 296, Loss: 0.1365
# Epoch: 297, Loss: 0.1366
# Epoch: 298, Loss: 0.1365
# Epoch: 299, Loss: 0.1365
# Epoch: 300, Loss: 0.1365
# Epoch: 301, Loss: 0.1365
# Epoch: 302, Loss: 0.1365
# Epoch: 303, Loss: 0.1365
# Epoch: 304, Loss: 0.1365
# Epoch: 305, Loss: 0.1364
# Epoch: 306, Loss: 0.1364
# Epoch: 307, Loss: 0.1364
# Epoch: 308, Loss: 0.1363
# Epoch: 309, Loss: 0.1363
# Epoch: 310, Loss: 0.1364
# Epoch: 311, Loss: 0.1364
# Epoch: 312, Loss: 0.1364
# Epoch: 313, Loss: 0.1364
# Epoch: 314, Loss: 0.1364
# Epoch: 315, Loss: 0.1363
# Epoch: 316, Loss: 0.1363
# Epoch: 317, Loss: 0.1362
# Epoch: 318, Loss: 0.1362
# Epoch: 319, Loss: 0.1362
# Epoch: 320, Loss: 0.1362
# Epoch: 321, Loss: 0.1363
# Epoch: 322, Loss: 0.1362
# Epoch: 323, Loss: 0.1362
# Epoch: 324, Loss: 0.1361
# Epoch: 325, Loss: 0.1361
# Epoch: 326, Loss: 0.1361
# Epoch: 327, Loss: 0.1361
# Epoch: 328, Loss: 0.1361
# Epoch: 329, Loss: 0.1361
# Epoch: 330, Loss: 0.1361
# Epoch: 331, Loss: 0.1361
# Epoch: 332, Loss: 0.1361
# Epoch: 333, Loss: 0.1360
# Epoch: 334, Loss: 0.1360
# Epoch: 335, Loss: 0.1360
# Epoch: 336, Loss: 0.1360
# Epoch: 337, Loss: 0.1360
# Epoch: 338, Loss: 0.1360
# Epoch: 339, Loss: 0.1360
# Epoch: 340, Loss: 0.1360
# Epoch: 341, Loss: 0.1359
# Epoch: 342, Loss: 0.1359
# Epoch: 343, Loss: 0.1359
# Epoch: 344, Loss: 0.1359
# Epoch: 345, Loss: 0.1359
# Epoch: 346, Loss: 0.1359
# Epoch: 347, Loss: 0.1359
# Epoch: 348, Loss: 0.1359
# Epoch: 349, Loss: 0.1359
# Epoch: 350, Loss: 0.1358
# Epoch: 351, Loss: 0.1358
# Epoch: 352, Loss: 0.1358
# Epoch: 353, Loss: 0.1358
# Epoch: 354, Loss: 0.1358
# Epoch: 355, Loss: 0.1358
# Epoch: 356, Loss: 0.1358
# Epoch: 357, Loss: 0.1358
# Epoch: 358, Loss: 0.1358
# Epoch: 359, Loss: 0.1358
# Epoch: 360, Loss: 0.1357
# Epoch: 361, Loss: 0.1357
# Epoch: 362, Loss: 0.1357
# Epoch: 363, Loss: 0.1357
# Epoch: 364, Loss: 0.1357
# Epoch: 365, Loss: 0.1357
# Epoch: 366, Loss: 0.1357
# Epoch: 367, Loss: 0.1357
# Epoch: 368, Loss: 0.1356
# Epoch: 369, Loss: 0.1356
# Epoch: 370, Loss: 0.1356
# Epoch: 371, Loss: 0.1356
# Epoch: 372, Loss: 0.1356
# Epoch: 373, Loss: 0.1356
# Epoch: 374, Loss: 0.1356
# Epoch: 375, Loss: 0.1356
# Epoch: 376, Loss: 0.1356
# Epoch: 377, Loss: 0.1356
# Epoch: 378, Loss: 0.1356
# Epoch: 379, Loss: 0.1356
# Epoch: 380, Loss: 0.1356
# Epoch: 381, Loss: 0.1357
# Epoch: 382, Loss: 0.1357
# Epoch: 383, Loss: 0.1357
# Epoch: 384, Loss: 0.1356
# Epoch: 385, Loss: 0.1355
# Epoch: 386, Loss: 0.1354
# Epoch: 387, Loss: 0.1354
# Epoch: 388, Loss: 0.1355
# Epoch: 389, Loss: 0.1355
# Epoch: 390, Loss: 0.1356
# Epoch: 391, Loss: 0.1355
# Epoch: 392, Loss: 0.1355
# Epoch: 393, Loss: 0.1354
# Epoch: 394, Loss: 0.1354
# Epoch: 395, Loss: 0.1354
# Epoch: 396, Loss: 0.1355
# Epoch: 397, Loss: 0.1355
# Epoch: 398, Loss: 0.1355
# Epoch: 399, Loss: 0.1354
# Epoch: 400, Loss: 0.1353
# Epoch: 401, Loss: 0.1353
# Epoch: 402, Loss: 0.1354
# Epoch: 403, Loss: 0.1354
# Epoch: 404, Loss: 0.1354
# Epoch: 405, Loss: 0.1354
# Epoch: 406, Loss: 0.1354
# Epoch: 407, Loss: 0.1353
# Epoch: 408, Loss: 0.1353
# Epoch: 409, Loss: 0.1353
# Epoch: 410, Loss: 0.1353
# Epoch: 411, Loss: 0.1353
# Epoch: 412, Loss: 0.1353
# Epoch: 413, Loss: 0.1353
# Epoch: 414, Loss: 0.1353
# Epoch: 415, Loss: 0.1353
# Epoch: 416, Loss: 0.1352
# Epoch: 417, Loss: 0.1352
# Epoch: 418, Loss: 0.1352
# Epoch: 419, Loss: 0.1352
# Epoch: 420, Loss: 0.1353
# Epoch: 421, Loss: 0.1352
# Epoch: 422, Loss: 0.1352
# Epoch: 423, Loss: 0.1352
# Epoch: 424, Loss: 0.1352
# Epoch: 425, Loss: 0.1352
# Epoch: 426, Loss: 0.1352
# Epoch: 427, Loss: 0.1352
# Epoch: 428, Loss: 0.1352
# Epoch: 429, Loss: 0.1352
# Epoch: 430, Loss: 0.1352
# Epoch: 431, Loss: 0.1352
# Epoch: 432, Loss: 0.1351
# Epoch: 433, Loss: 0.1351
# Epoch: 434, Loss: 0.1351
# Epoch: 435, Loss: 0.1351
# Epoch: 436, Loss: 0.1351
# Epoch: 437, Loss: 0.1351
# Epoch: 438, Loss: 0.1351
# Epoch: 439, Loss: 0.1351
# Epoch: 440, Loss: 0.1351
# Epoch: 441, Loss: 0.1351
# Epoch: 442, Loss: 0.1351
# Epoch: 443, Loss: 0.1351
# Epoch: 444, Loss: 0.1351
# Epoch: 445, Loss: 0.1351
# Epoch: 446, Loss: 0.1351
# Epoch: 447, Loss: 0.1350
# Epoch: 448, Loss: 0.1350
# Epoch: 449, Loss: 0.1350
# Epoch: 450, Loss: 0.1350
# Epoch: 451, Loss: 0.1350
# Epoch: 452, Loss: 0.1351
# Epoch: 453, Loss: 0.1351
# Epoch: 454, Loss: 0.1351
# Epoch: 455, Loss: 0.1351
# Epoch: 456, Loss: 0.1351
# Epoch: 457, Loss: 0.1351
# Epoch: 458, Loss: 0.1351
# Epoch: 459, Loss: 0.1350
# Epoch: 460, Loss: 0.1349
# Epoch: 461, Loss: 0.1349
# Epoch: 462, Loss: 0.1349
# Epoch: 463, Loss: 0.1349
# Epoch: 464, Loss: 0.1350
# Epoch: 465, Loss: 0.1350
# Epoch: 466, Loss: 0.1350
# Epoch: 467, Loss: 0.1351
# Epoch: 468, Loss: 0.1350
# Epoch: 469, Loss: 0.1350
# Epoch: 470, Loss: 0.1349
# Epoch: 471, Loss: 0.1349
# Epoch: 472, Loss: 0.1349
# Epoch: 473, Loss: 0.1349
# Epoch: 474, Loss: 0.1349
# Epoch: 475, Loss: 0.1349
# Epoch: 476, Loss: 0.1350
# Epoch: 477, Loss: 0.1350
# Epoch: 478, Loss: 0.1350
# Epoch: 479, Loss: 0.1349
# Epoch: 480, Loss: 0.1349
# Epoch: 481, Loss: 0.1349
# Epoch: 482, Loss: 0.1349
# Epoch: 483, Loss: 0.1349
# Epoch: 484, Loss: 0.1349
# Epoch: 485, Loss: 0.1349
# Epoch: 486, Loss: 0.1349
# Epoch: 487, Loss: 0.1349
# Epoch: 488, Loss: 0.1349
# Epoch: 489, Loss: 0.1349
# Epoch: 490, Loss: 0.1348
# Epoch: 491, Loss: 0.1348
# Epoch: 492, Loss: 0.1348
# Epoch: 493, Loss: 0.1348
# Epoch: 494, Loss: 0.1348
# Epoch: 495, Loss: 0.1348
# Epoch: 496, Loss: 0.1348
# Epoch: 497, Loss: 0.1348
# Epoch: 498, Loss: 0.1348
# Epoch: 499, Loss: 0.1348
# Test Accuracy: 0.8595
