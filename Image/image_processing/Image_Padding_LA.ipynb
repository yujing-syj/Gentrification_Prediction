# %%
import os
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = r'/content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped'
dest = r'/content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/padding'

# %%
categories = os.listdir(path)

# %%
width = []
length = []

for c in categories:
  img_dir = os.path.join(path, c)
  for img in tqdm(os.listdir(img_dir)):
    img_arr = cv2.imread(os.path.join(img_dir, img),cv2.IMREAD_COLOR)
    print(os.path.join(img_dir, img))
    width.append(img_arr.shape[0])
    length.append(img_arr.shape[1])
# Out:
#   0%|          | 1/273 [00:01<04:55,  1.09s/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037104105.png
#   1%|          | 2/273 [00:02<05:44,  1.27s/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037104320.png
#   1%|          | 3/273 [00:23<47:00, 10.45s/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037104610.png
#   2%|▏         | 5/273 [00:24<18:52,  4.23s/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037104822.png
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037119320.png
#   2%|▏         | 6/273 [00:24<12:38,  2.84s/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037119341.png
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037119342.png
#   3%|▎         | 8/273 [00:25<06:55,  1.57s/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037120104.png
#   3%|▎         | 9/273 [00:25<05:31,  1.26s/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037123204.png
#   4%|▎         | 10/273 [00:25<04:26,  1.01s/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037123420.png
#   4%|▍         | 12/273 [00:26<02:38,  1.64it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037123520.png
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037124105.png
#   5%|▌         | 14/273 [00:26<01:48,  2.40it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037124203.png
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037124204.png
#   5%|▌         | 15/273 [00:27<01:53,  2.28it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037125310.png
#   6%|▌         | 17/273 [00:27<01:16,  3.33it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037125320.png
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037127103.png
#   7%|▋         | 19/273 [00:28<01:07,  3.77it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037127104.png
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037127606.png
#   7%|▋         | 20/273 [00:28<01:04,  3.90it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037127804.png
#   8%|▊         | 21/273 [00:28<01:01,  4.10it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037128220.png
#   8%|▊         | 22/273 [00:28<01:10,  3.55it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037134304.png
#   8%|▊         | 23/273 [00:29<01:17,  3.22it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037183104.png
#   9%|▉         | 24/273 [00:29<01:13,  3.37it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037183220.png
#   9%|▉         | 25/273 [00:29<01:14,  3.34it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037183221.png
#  10%|▉         | 26/273 [00:30<01:26,  2.87it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037183222.png
#  10%|▉         | 27/273 [00:30<01:15,  3.25it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037183401.png
#  10%|█         | 28/273 [00:30<01:09,  3.54it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037183510.png
#  11%|█         | 30/273 [00:31<00:58,  4.16it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037183520.png
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037183610.png
#  11%|█▏        | 31/273 [00:31<00:58,  4.15it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037183620.png
#  12%|█▏        | 32/273 [00:31<01:02,  3.83it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037183701.png
#  12%|█▏        | 33/273 [00:32<01:16,  3.14it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037183702.png
#  12%|█▏        | 34/273 [00:32<01:09,  3.46it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037183810.png
#  13%|█▎        | 35/273 [00:32<01:19,  3.00it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037185204.png
#  13%|█▎        | 36/273 [00:33<01:34,  2.52it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037186301.png
#  14%|█▎        | 37/273 [00:33<01:46,  2.21it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037186401.png
#  14%|█▍        | 38/273 [00:34<01:36,  2.44it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037186403.png
#  14%|█▍        | 39/273 [00:34<01:35,  2.45it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037187101.png
#  15%|█▌        | 41/273 [00:37<02:47,  1.38it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037187102.png
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037190510.png
#  16%|█▌        | 43/273 [00:37<01:41,  2.27it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037190520.png
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037190801.png
#  16%|█▋        | 45/273 [00:37<01:25,  2.68it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037190802.png
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037190902.png
#  17%|█▋        | 47/273 [00:38<00:58,  3.84it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037191110.png
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037191120.png
#  18%|█▊        | 48/273 [00:38<00:55,  4.02it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037191201.png
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037191204.png
#  18%|█▊        | 50/273 [00:38<00:40,  5.44it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037191301.png
#  19%|█▉        | 52/273 [00:39<00:41,  5.33it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified/06037
/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/non-gentrified/06037481606.png
#   1%|          | 7/1394 [00:07<21:54,  1.05it/s]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/non-gentrified/06037481711.png
#   1%|          | 8/1394 [00:09<32:40,  1.41s/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/non-gentrified/06037481901.png
#   1%|          | 9/1394 [00:10<29:34,  1.28s/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/non-gentrified/06037481902.png
#   1%|          | 10/1394 [00:12<33:37,  1.46s/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/non-gentrified/06037482001.png
#   1%|          | 11/1394 [00:14<35:29,  1.54s/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/non-gentrified/06037482002.png
#   1%|          | 12/1394 [00:15<32:06,  1.39s/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/non-gentrified/06037482101.png
#   1%|          | 13/1394 [00:16<29:42,  1.29s/it]
# /content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/non-gentrified/06037482102.png

# %%
sns.boxplot(data = width)
plt.show()

# %%
sns.boxplot(data = length)
plt.show()

# %%
count = 0
for i,w in enumerate(width):
  if w > 20000 or length[i] > 20000:
    count += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1c1e8a8bec05> in <module>()
#       1 count = 0
# ----> 2 for i,w in enumerate(width):
#       3   if w > 20000 or length[i] > 20000:
#       4     count += 1
#
# NameError: name 'width' is not defined

# %%
count
# Out:
# 15

# %%
count = 0
for i,w in enumerate(width):
  if w <= 20000 and length[i] <= 20000:
    count += 1

# %%
count
# Out:
# 1652

# %%
273+1394-1652
# Out:
# 15

# %%
max(width)
# Out:
# 25151

# %%
max(length)
# Out:
# 30865

# %%
max_width = 20000 #max(width)
max_len = 20000 #max(length)

# %%
print(max_width, max_len)
# Out:
# 20000 20000

# %%
# max_width = 18288
# max_len = 21653

# %%
for c in categories:
  img_dir = os.path.join(path, c)
  for img in  tqdm(os.listdir(img_dir)):
    png = img#.strip('.tif')# + '.png'
    if png in os.listdir(os.path.join(dest, c)):
      continue

    img_arr = cv2.imread(os.path.join(img_dir, img), cv2.IMREAD_COLOR)
    if img_arr.shape[0] <= 20000 and img_arr.shape[1] <= 20000:
      pad_width = max_width - img_arr.shape[0]
      pad_len = max_len - img_arr.shape[1]
      padded_img = np.pad(img_arr, pad_width=[(0, pad_width), (0, pad_len),(0, 0)], mode = 'constant')
      folder = os.path.join(dest, c)
      cv2.imwrite(os.path.join(folder, img), padded_img)
      print(os.path.join(folder, img.strip('.tif')))
# Out:
# 100%|██████████| 273/273 [00:05<00:00, 49.65it/s]
# 100%|██████████| 1394/1394 [01:20<00:00, 17.26it/s]

# %%
len(os.listdir(os.path.join(dest, 'gentrified')))
# Out:
# 272

# %%
len(os.listdir(os.path.join(dest, 'non-gentrified')))
# Out:
# 1380

# %%
for c in categories:
  img_dir = os.path.join(path, c)
  for img in  os.listdir(img_dir):
    print(img)
    break
# Out:
# 17031010100.png
# 17031120100.png

# %%
img_arr = cv2.imread(os.path.join(r'/content/drive/My Drive/Colab Notebooks/MACS 37000/final project/LA/cropped/gentrified', '06037603004.png'), cv2.IMREAD_COLOR)

# %%
img_arr.shape
# Out:
# (1806, 3236, 3)

# %%
plt.imshow(cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB))

# %%
import numpy as np

pad_width = max_width - img_arr.shape[0]
pad_len = max_len - img_arr.shape[1]
padded_img = np.pad(img_arr, pad_width=[(0, pad_width), (0, pad_len),(0, 0)], mode = 'constant')

# %%
plt.imshow(cv2.cvtColor(padded_img, cv2.COLOR_BGR2RGB))

# %%
cv2.imwrite('test.png', padded_img)
# Out:
# False

# %%
padded_img.shape
# Out:
# (18288, 21653, 3)
